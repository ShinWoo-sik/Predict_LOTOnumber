# %% [markdown]
# #### 로또 번호 예측

# %%
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
import numpy as np
from skopt import gp_minimize
from skopt.space import Integer

# 번호의 중복 제거 및 부족 시 채워주는 함수
def ensure_unique_numbers(numbers):
    numbers = list(set(numbers))  # 중복 제거
    while len(numbers) < 6:
        numbers.append(random.randint(1, 45))  # 부족한 번호를 무작위로 추가
    return sorted(numbers[:6])

# 실제 번호와 예측 번호를 비교하여 보상을 계산하는 함수
def calculate_rewards(actual, predicted):
    match_count = len(set(actual) & set(predicted))  # 일치하는 번호 개수 계산
    rewards = {6: 10_000_000_000, 5: 1_499_000, 4: 49_000, 3: 4_000}
    return rewards.get(match_count, -1_000)  # 일치하지 않으면 -1,000 반환

# 앙상블 예측 함수
def predict_ensemble_from_numpy(predictions_list):
    """
    각 모델의 예측값을 numpy array로 받아 앙상블 예측 수행.
    """
    flat_predictions = np.concatenate(predictions_list).flatten()
    flat_predictions = flat_predictions[(flat_predictions >= 1) & (flat_predictions <= 45)]  # 유효 번호 필터링
    frequency_counts = pd.Series(flat_predictions).value_counts()

    if frequency_counts.empty:
        print("빈도 계산 결과가 없습니다. 빈 결과를 반환합니다.")
        return []

    return ensure_unique_numbers(frequency_counts.nlargest(6).index.tolist())

# 예측 모델의 성능을 평가하는 함수
def evaluate_predictions(data, prediction_functions, weeks_to_evaluate=52):
    total_rewards = {method: {"total_reward": 0, "win_count": 0} for method in prediction_functions.keys()}
    total_rewards["Ensemble"] = {"total_reward": 0, "win_count": 0}  # 앙상블 결과 추가
    prediction_storage = {method: [] for method in prediction_functions.keys()}

    for weeks_ago in range(weeks_to_evaluate, 0, -1):
        train_data = data[:-weeks_ago]
        test_data = data.iloc[-weeks_ago].values[2:]

        print(f"\n### ({weeks_ago}주전)예측되는 번호와 당첨 금액 ###")
        print(f"=> 실제 당첨 번호           : {sorted(test_data)}")

        for method, func in prediction_functions.items():
            predicted = func(train_data, weeks_ago)
            predicted = ensure_unique_numbers(predicted)

            if not predicted:
                print(f"{method}의 예측 결과가 비어 있습니다.")
                continue

            prediction_storage[method].append(predicted)  # 숫자 리스트 저장
            reward = calculate_rewards(test_data, predicted)
            total_rewards[method]["total_reward"] += reward
            if reward > 0:
                total_rewards[method]["win_count"] += 1

            print(f"{method}: {sorted(predicted)} (당첨금: {reward}원)")

        # 앙상블 예측 수행
        ensemble_predictions = predict_ensemble_from_numpy(
            [np.array(prediction_storage[method]) for method in prediction_storage]
        )
        ensemble_reward = calculate_rewards(test_data, ensemble_predictions)
        total_rewards["Ensemble"]["total_reward"] += ensemble_reward
        if ensemble_reward > 0:
            total_rewards["Ensemble"]["win_count"] += 1

        print(f"Ensemble                    : {ensemble_predictions} (당첨금: {ensemble_reward}원)")

    return total_rewards

# 높은 빈도의 숫자를 기반으로 예측
def predict_high_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nlargest(6).index.tolist()  # 상위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 낮은 빈도의 숫자를 기반으로 예측
def predict_low_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nsmallest(6).index.tolist()  # 하위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 높은 빈도 3개 + 낮은 빈도 3개 조합으로 예측
def predict_combined_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    most_frequent = frequency_counts.nlargest(3).index.tolist()  # 상위 3개 숫자
    least_frequent = frequency_counts.nsmallest(3).index.tolist()  # 하위 3개 숫자
    return ensure_unique_numbers(most_frequent + least_frequent)

# PCA를 사용하여 다음 벡터를 예측
def predict_next_vector(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(numbers)  # 데이터 스케일링

    pca = PCA(n_components=1)
    principal_component = pca.fit_transform(scaled_data)  # PCA 변환

    next_vector = principal_component[-1] + (principal_component[-1] - principal_component[-2])  # 다음 벡터 예측
    inverse_scaled_vector = scaler.inverse_transform(scaled_data.mean(axis=0).reshape(1, -1)) + next_vector

    predicted_numbers = [int(round(num)) for num in inverse_scaled_vector[0] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# 신경망을 사용하여 번호를 예측
def predict_neural_network(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(6, activation='sigmoid')  # Using sigmoid to restrict range
    ])

    model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mae'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])

    # Add random noise (jitter) to each prediction
    jittered_predictions = predictions + np.random.uniform(-0.05, 0.05, size=predictions.shape)
    jittered_predictions = np.clip(jittered_predictions, 0, 1)  # Ensure valid range for sigmoid outputs

    # Inverse transform to original scale
    inverse_transformed = scaler_y.inverse_transform(jittered_predictions)

    # Convert to integers and ensure range
    rounded_numbers = [int(round(num)) for num in inverse_transformed.flatten() if 1 <= round(num) <= 45]
    return ensure_unique_numbers(rounded_numbers[:6])

# 랜덤 포레스트를 사용하여 번호를 예측
def predict_random_forest(data, weeks_ago):
    from sklearn.ensemble import RandomForestRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# Gradient Boosting을 사용하여 번호를 예측
def predict_gradient_boosting(data, weeks_ago):
    from sklearn.ensemble import GradientBoostingRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    y_train = y_train.iloc[:, 0].values
    y_test = y_test.iloc[:, 0].values

    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# LSTM을 사용하여 번호를 예측
def predict_lstm(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(numbers)

    X, y = [], []
    for i in range(len(scaled_data) - 10):
        X.append(scaled_data[i:i + 10])
        y.append(scaled_data[i + 10])

    X, y = np.array(X), np.array(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(128, return_sequences=True),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(6, activation='linear')
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])
    predicted_numbers = scaler.inverse_transform(predictions).flatten()
    return ensure_unique_numbers([int(round(num)) for num in predicted_numbers if 1 <= round(num) <= 45])

# Bayesian Optimization을 사용하여 번호를 예측
def predict_bayesian(data, weeks_ago):
    numbers = data.iloc[:, 2:].values

    def objective_function(x):
        selected_numbers = x
        count = sum(num in selected_numbers for num in numbers.flatten())
        return -count

    search_space = [Integer(1, 45) for _ in range(6)]
    result = gp_minimize(objective_function, search_space, n_calls=100)
    return ensure_unique_numbers(result.x)

# K-평균 클러스터링을 사용하여 번호를 예측
def predict_kmeans_clustering(data, weeks_ago, n_clusters=5):
    numbers = data.iloc[:, 2:].values.flatten().reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(numbers)

    # 가장 빈번한 클러스터 선택
    cluster_counts = pd.Series(kmeans.labels_).value_counts()
    top_cluster = cluster_counts.idxmax()
    top_numbers = numbers[kmeans.labels_ == top_cluster]

    # 상위 6개의 번호 선택
    predicted_numbers = pd.Series(top_numbers.flatten()).value_counts().nlargest(6).index.tolist()
    return ensure_unique_numbers(predicted_numbers)

# 오토인코더를 사용하여 번호를 예측
def predict_autoencoder(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(numbers)

    # 오토인코더 정의
    input_dim = scaled_data.shape[1]
    autoencoder = Sequential([
        Input(shape=(input_dim,)),
        Dense(16, activation='relu'),
        Dense(input_dim, activation='sigmoid')
    ])
    autoencoder.compile(optimizer='adam', loss='mse')
    autoencoder.fit(scaled_data, scaled_data, epochs=50, batch_size=16, verbose=0)

    # 복원된 데이터로 패턴 분석
    decoded_data = autoencoder.predict(scaled_data)
    predicted_numbers = [int(round(num)) for num in decoded_data[-1] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# Markov Chain을 사용하여 번호를 예측
def predict_markov_chain(data, weeks_ago):
    numbers = data.iloc[:, 2:].values.flatten()
    transitions = pd.crosstab(numbers[:-1], numbers[1:])
    probabilities = transitions.div(transitions.sum(axis=1), axis=0)

    last_number = numbers[-1]
    if last_number in probabilities.index:
        next_numbers = probabilities.loc[last_number].nlargest(6).index.tolist()
    else:
        next_numbers = random.sample(range(1, 46), 6)  # 기본값으로 랜덤 샘플 제공

    return ensure_unique_numbers(next_numbers)

# 메인 함수
def main():
    try:
        file_path = "Loto_number.xlsx"  # 엑셀 파일 경로
        data = pd.read_excel(file_path)
    except Exception as e:
        print(f"데이터 로드 실패: {e}")
        return

    # 예측 함수 매핑
    prediction_functions = {
        "total_high_frequency        ": predict_high_frequency_numbers,
        "total_low_frequency         ": predict_low_frequency_numbers,
        "total_combined_frequency    ": predict_combined_frequency_numbers,
        "total_next_vector           ": predict_next_vector,

        "recent_52_high_frequency    ": predict_high_frequency_numbers,
        "recent_52_low_frequency     ": predict_low_frequency_numbers,
        "recent_52_combined_frequency": predict_combined_frequency_numbers,
        "recent_52_next_vector       ": predict_next_vector,

        "recent_26_high_frequency    ": predict_high_frequency_numbers,
        "recent_26_low_frequency     ": predict_low_frequency_numbers,
        "recent_26_combined_frequency": predict_combined_frequency_numbers,
        "recent_26_next_vector       ": predict_next_vector,

        "neural_network              ": predict_neural_network,
        "random_forest               ": predict_random_forest,
        "gradient_boosting           ": predict_gradient_boosting,
        "LSTM                        ": predict_lstm,
        "Bayesian                    ": predict_bayesian,
        "KMeans                      ": predict_kmeans_clustering,
        "AutoEncoder                 ": predict_autoencoder,
        "MarkovChain                 ": predict_markov_chain
    }

    # 모델 성능 평가
    total_rewards = evaluate_predictions(data, prediction_functions)

    print("\n### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###")
    for method, stats in total_rewards.items():
        total_reward = stats["total_reward"]
        win_count = stats["win_count"]
        print(f"{method}: 총 당첨 {total_reward}원({win_count}회)")
           
    print("\n### 다음 주 예상 번호 ###")
    all_predictions = []  # 모든 예측 결과를 저장할 리스트
    for method, func in prediction_functions.items():
        try:
            predicted = func(data, weeks_ago=1)
            predicted = ensure_unique_numbers(predicted)
            all_predictions.append(predicted)  # 앙상블에 포함할 결과 저장
            print(f"{method}: {predicted}")
        except Exception as e:
            print(f"{method}: 예측 실패 (오류: {e})")

    # 앙상블 예측 수행
    if all_predictions:
        ensemble_predictions = predict_ensemble_from_numpy([np.array(pred) for pred in all_predictions])
        print(f"\nEnsemble                    : {ensemble_predictions}")

if __name__ == "__main__":
    main()
# Out:
# ### (52주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 7, 13, 28, 36, 42]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# neural_network              : [5, 16, 17, 25, 35, 41] (당첨금: -1000원)
# random_forest               : [6, 12, 19, 28, 33, 38] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 7, 8, 10] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step
# LSTM                        : [7, 13, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [11, 16, 27, 33, 43, 45] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023DE75FBC40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 20, 21, 23, 34, 42] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 6, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 16, 18, 20, 21] (당첨금: -1000원)
#
# ### (51주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [13, 14, 22, 26, 37, 38]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# neural_network              : [3, 11, 19, 27, 33, 38] (당첨금: -1000원)
# random_forest               : [6, 15, 20, 28, 34, 41] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 7, 8, 32, 33] (당첨금: -1000원)
# WARNING:tensorflow:5 out of the last 19 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023DF0A35580> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# LSTM                        : [6, 7, 12, 32, 39, 40] (당첨금: -1000원)
# Bayesian                    : [3, 7, 12, 16, 18, 33] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 18, 30, 37, 39] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 5, 7, 43, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (50주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 12, 29, 31, 40, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [7, 17, 21, 28, 39, 41] (당첨금: -1000원)
# random_forest               : [6, 13, 20, 26, 35, 41] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 8, 26, 31] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# LSTM                        : [7, 12, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [7, 12, 14, 18, 33, 36] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 11, 27, 29, 33] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (49주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 7, 21, 30, 35, 38]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# neural_network              : [3, 13, 17, 29, 37, 43] (당첨금: -1000원)
# random_forest               : [9, 13, 22, 27, 33, 39] (당첨금: -1000원)
# gradient_boosting           : [2, 3, 5, 6, 8, 10] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# LSTM                        : [6, 12, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [18, 21, 33, 35, 38, 45] (당첨금: 4000원)
# KMeans                      : [2, 3, 6, 7, 11, 12] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 20, 28, 40, 45] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (48주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 16, 34, 37, 39, 40]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# neural_network              : [7, 16, 19, 25, 30, 39] (당첨금: -1000원)
# random_forest               : [6, 13, 21, 26, 35, 39] (당첨금: -1000원)
# gradient_boosting           : [2, 6, 7, 8, 10, 23] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# LSTM                        : [7, 13, 14, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [3, 7, 12, 18, 33, 39] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 8, 15, 26, 33, 42] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (47주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 3, 4, 29, 42, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [6, 11, 15, 26, 32, 39] (당첨금: -1000원)
# random_forest               : [9, 14, 21, 30, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [1, 2, 6, 7, 8, 11] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step
# LSTM                        : [7, 8, 12, 33, 34, 39] (당첨금: -1000원)
# Bayesian                    : [16, 18, 21, 34, 38, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 4, 12, 16, 17, 26] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (46주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 14, 30, 31, 40, 41]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# neural_network              : [8, 14, 18, 21, 30, 40] (당첨금: 4000원)
# random_forest               : [6, 12, 20, 23, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 7, 8, 13, 30] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step
# LSTM                        : [7, 14, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [2, 7, 11, 18, 38, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 8, 18, 35, 36, 38] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (45주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 19, 26, 37, 39, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [4, 9, 23, 26, 33, 43] (당첨금: -1000원)
# random_forest               : [9, 16, 23, 29, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [2, 6, 7, 9, 13, 14] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# LSTM                        : [6, 7, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [6, 18, 21, 36, 43, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 8, 19, 26, 28, 39] (당첨금: 4000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (44주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 12, 13, 19, 33, 40]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# neural_network              : [8, 15, 24, 27, 33, 42] (당첨금: -1000원)
# random_forest               : [8, 15, 22, 31, 35, 42] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 9, 26, 31] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# LSTM                        : [7, 13, 33, 34, 40, 41] (당첨금: 4000원)
# Bayesian                    : [6, 16, 19, 33, 34, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 12, 20, 21, 37] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (43주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 7, 11, 20, 22, 41]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# neural_network              : [6, 13, 18, 25, 35, 40] (당첨금: -1000원)
# random_forest               : [9, 16, 23, 28, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 8, 11] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step
# LSTM                        : [6, 12, 32, 33, 38, 39] (당첨금: -1000원)
# Bayesian                    : [6, 12, 16, 18, 36, 45] (당첨금: -1000원)
# KMeans                      : [3, 6, 7, 11, 12, 13] (당첨금: 4000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AutoEncoder                 : [1, 6, 8, 21, 21, 42] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (42주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 13, 30, 33, 43, 45]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [7, 19, 23, 29, 34, 40] (당첨금: -1000원)
# random_forest               : [5, 10, 17, 22, 31, 36] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 11, 45] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# LSTM                        : [7, 14, 20, 32, 39, 40] (당첨금: -1000원)
# Bayesian                    : [3, 13, 18, 33, 38, 41] (당첨금: 4000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 9, 23, 35, 45] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (41주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [16, 20, 26, 36, 42, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# total_next_vector           : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# neural_network              : [5, 8, 17, 31, 37, 40] (당첨금: -1000원)
# random_forest               : [7, 16, 23, 29, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [1, 4, 5, 6, 16, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# LSTM                        : [7, 13, 34, 35, 40, 41] (당첨금: -1000원)
# Bayesian                    : [11, 12, 18, 23, 33, 39] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 22, 32, 39, 44] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (40주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [11, 13, 20, 21, 32, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# neural_network              : [6, 11, 20, 27, 32, 39] (당첨금: 4000원)
# random_forest               : [6, 12, 20, 28, 33, 41] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 28, 32, 40] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# LSTM                        : [6, 12, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [3, 11, 16, 33, 43, 45] (당첨금: -1000원)
# KMeans                      : [2, 3, 6, 7, 11, 12] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step
# AutoEncoder                 : [1, 8, 11, 31, 38, 44] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: 4000원)
#
# ### (39주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 16, 19, 32, 33, 38]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# total_next_vector           : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# recent_52_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# recent_26_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# neural_network              : [8, 10, 19, 30, 35, 41] (당첨금: -1000원)
# random_forest               : [8, 13, 20, 29, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 7, 32, 40] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# LSTM                        : [6, 7, 13, 32, 39, 40] (당첨금: -1000원)
# Bayesian                    : [1, 19, 21, 39, 43, 45] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 12, 15, 31, 39, 40] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (38주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 12, 23, 32, 34, 36]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# total_next_vector           : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# neural_network              : [5, 13, 21, 25, 30, 42] (당첨금: -1000원)
# random_forest               : [6, 13, 19, 27, 33, 41] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 7, 9, 29] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# LSTM                        : [7, 14, 15, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [6, 7, 11, 12, 18, 21] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 14, 16, 18] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 20, 34, 42, 42, 45] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (37주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [15, 16, 17, 25, 30, 31]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# total_next_vector           : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [11, 16, 17, 28, 29, 35] (당첨금: -1000원)
# random_forest               : [5, 12, 19, 26, 33, 38] (당첨금: -1000원)
# gradient_boosting           : [2, 5, 6, 27, 29, 33] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step
# LSTM                        : [6, 12, 13, 32, 39, 40] (당첨금: -1000원)
# Bayesian                    : [12, 17, 21, 31, 39, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 7, 11, 40, 44] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (36주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 4, 9, 30, 33, 36]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# neural_network              : [4, 14, 18, 24, 31, 42] (당첨금: -1000원)
# random_forest               : [8, 14, 21, 27, 33, 39] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 9, 45] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# LSTM                        : [7, 8, 34, 35, 40, 41] (당첨금: -1000원)
# Bayesian                    : [7, 12, 18, 21, 38, 45] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 14, 29, 34, 39] (당첨금: -1000원)
# MarkovChain                 : [32, 33, 34, 35, 36, 39] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (35주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [11, 13, 14, 15, 16, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# neural_network              : [6, 14, 20, 28, 30, 41] (당첨금: -1000원)
# random_forest               : [8, 12, 20, 26, 36, 40] (당첨금: -1000원)
# gradient_boosting           : [2, 3, 4, 6, 7, 18] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# LSTM                        : [7, 13, 21, 33, 40, 41] (당첨금: -1000원)
# Bayesian                    : [12, 16, 19, 24, 33, 45] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 15, 25, 26, 45] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (34주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 9, 12, 13, 20, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# total_next_vector           : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# recent_52_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# recent_26_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# neural_network              : [9, 10, 17, 18, 32, 36] (당첨금: -1000원)
# random_forest               : [7, 13, 20, 25, 35, 42] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 8, 10, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# LSTM                        : [7, 12, 19, 20, 33, 40] (당첨금: -1000원)
# Bayesian                    : [6, 12, 18, 33, 34, 38] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 8, 26, 27, 29, 33] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (33주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [2, 19, 26, 31, 38, 41]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# neural_network              : [7, 14, 21, 25, 30, 40] (당첨금: -1000원)
# random_forest               : [8, 13, 20, 26, 33, 40] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 7, 8, 10] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# LSTM                        : [7, 14, 20, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [2, 12, 18, 33, 38, 39] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 14, 16, 18] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 10, 25, 37, 38, 44] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (32주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 24, 31, 32, 38, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [6, 12, 19, 25, 34, 42] (당첨금: -1000원)
# random_forest               : [8, 13, 21, 27, 31, 39] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 8, 9, 26] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# LSTM                        : [7, 13, 14, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [6, 12, 16, 18, 30, 38] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 19, 24, 32, 33, 35] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (31주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 6, 21, 30, 34, 35]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [8, 17, 20, 21, 30, 42] (당첨금: -1000원)
# random_forest               : [6, 11, 19, 27, 35, 41] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 9, 22] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# LSTM                        : [7, 13, 14, 32, 33, 40] (당첨금: -1000원)
# Bayesian                    : [6, 7, 13, 14, 33, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 28, 30, 32, 40, 41] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (30주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [13, 19, 21, 24, 34, 35]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# neural_network              : [8, 12, 20, 24, 39, 40] (당첨금: -1000원)
# random_forest               : [8, 15, 20, 26, 35, 41] (당첨금: -1000원)
# gradient_boosting           : [3, 4, 5, 6, 9, 10] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# LSTM                        : [6, 13, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [1, 12, 19, 21, 39, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 5, 9, 10, 20, 42] (당첨금: -1000원)
# MarkovChain                 : [36, 37, 38, 39, 42, 43] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (29주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 8, 17, 30, 33, 34]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# total_next_vector           : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# recent_52_next_vector       : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# recent_26_next_vector       : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# neural_network              : [10, 21, 30, 32, 39, 40] (당첨금: -1000원)
# random_forest               : [8, 12, 22, 29, 36, 42] (당첨금: -1000원)
# gradient_boosting           : [3, 6, 7, 9, 25, 27] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# LSTM                        : [6, 13, 20, 26, 33, 40] (당첨금: -1000원)
# Bayesian                    : [12, 13, 18, 30, 33, 45] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 4, 32, 34, 36, 37] (당첨금: -1000원)
# MarkovChain                 : [36, 37, 38, 39, 42, 43] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (28주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 14, 25, 33, 40, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [4, 11, 17, 27, 36, 39] (당첨금: -1000원)
# random_forest               : [6, 13, 20, 26, 34, 41] (당첨금: -1000원)
# gradient_boosting           : [2, 4, 6, 7, 8, 13] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# LSTM                        : [7, 13, 19, 24, 38, 39] (당첨금: -1000원)
# Bayesian                    : [6, 12, 18, 19, 38, 43] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 17, 34, 36, 38, 44] (당첨금: -1000원)
# MarkovChain                 : [35, 36, 37, 38, 39, 42] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (27주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [4, 5, 9, 11, 37, 40]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [6, 11, 19, 29, 37, 40] (당첨금: 4000원)
# random_forest               : [7, 10, 18, 25, 33, 38] (당첨금: -1000원)
# gradient_boosting           : [3, 6, 8, 10, 18, 25] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# LSTM                        : [6, 12, 19, 26, 32, 39] (당첨금: -1000원)
# Bayesian                    : [18, 21, 24, 26, 33, 39] (당첨금: -1000원)
# KMeans                      : [30, 31, 33, 34, 35, 36] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 11, 12, 14, 28, 35] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (26주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 15, 24, 30, 31, 37]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [6, 11, 21, 26, 35, 41] (당첨금: -1000원)
# random_forest               : [6, 14, 18, 25, 32, 41] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 9, 11, 12, 42] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# LSTM                        : [6, 13, 19, 20, 33, 39] (당첨금: -1000원)
# Bayesian                    : [1, 12, 33, 38, 39, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 5, 7, 10, 21, 26] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (25주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 5, 8, 16, 28, 33]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [5, 14, 15, 22, 31, 40] (당첨금: -1000원)
# random_forest               : [7, 12, 19, 23, 33, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 8, 10, 11, 25] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# LSTM                        : [6, 7, 13, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [1, 3, 6, 11, 18, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 11, 30, 37, 40] (당첨금: -1000원)
# MarkovChain                 : [38, 39, 40, 41, 42, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (24주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [5, 10, 11, 17, 28, 34]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [7, 13, 20, 26, 28, 33] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [7, 13, 20, 26, 33, 41] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [7, 13, 20, 22, 26, 33] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [8, 13, 19, 22, 33, 38] (당첨금: -1000원)
# random_forest               : [7, 12, 20, 24, 35, 39] (당첨금: -1000원)
# gradient_boosting           : [3, 7, 8, 9, 11, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# LSTM                        : [7, 13, 14, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [16, 18, 26, 31, 33, 43] (당첨금: -1000원)
# ...
# recent_26_next_vector       : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# neural_network              : [5, 12, 22, 27, 36, 42] (당첨금: -1000원)
# random_forest               : [5, 13, 22, 26, 35, 41] (당첨금: -1000원)
# gradient_boosting           : [6, 7, 8, 9, 19, 25] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# LSTM                        : [7, 14, 33, 34, 40, 41] (당첨금: -1000원)
# Bayesian                    : [7, 12, 13, 18, 21, 24] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 16, 24, 28, 30, 39] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (8주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [2, 11, 31, 33, 37, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [2, 8, 15, 21, 28, 34] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [2, 8, 15, 21, 28, 34] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [2, 8, 15, 21, 28, 34] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [9, 11, 13, 24, 30, 40] (당첨금: -1000원)
# random_forest               : [8, 11, 20, 25, 30, 37] (당첨금: -1000원)
# gradient_boosting           : [6, 7, 9, 13, 23, 28] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# LSTM                        : [6, 13, 19, 32, 33, 39] (당첨금: -1000원)
# Bayesian                    : [19, 21, 24, 33, 34, 45] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step
# AutoEncoder                 : [1, 10, 13, 40, 42, 45] (당첨금: -1000원)
# MarkovChain                 : [35, 36, 37, 38, 39, 42] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (7주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 11, 17, 19, 40, 43]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [12, 18, 25, 31, 38, 45] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [12, 18, 25, 31, 38, 45] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [12, 18, 25, 31, 38, 45] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# neural_network              : [5, 12, 14, 28, 37, 40] (당첨금: -1000원)
# random_forest               : [8, 14, 21, 27, 32, 39] (당첨금: -1000원)
# gradient_boosting           : [1, 6, 7, 8, 10, 29] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# LSTM                        : [6, 13, 20, 26, 31, 40] (당첨금: -1000원)
# Bayesian                    : [6, 12, 21, 33, 38, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 21, 23, 25, 37, 43] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (6주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 11, 24, 26, 27, 37]
# total_high_frequency        : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [8, 12, 25, 27, 32, 41] (당첨금: -1000원)
# random_forest               : [9, 15, 21, 26, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 7, 8, 9, 24] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# LSTM                        : [7, 8, 14, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [1, 11, 12, 15, 33, 38] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 9, 25, 37, 43] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 6, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (5주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 6, 13, 15, 16, 22]
# total_high_frequency        : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [6, 13, 19, 26, 32, 39] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 13, 19, 26, 32, 39] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 13, 19, 26, 32, 39] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [7, 12, 20, 21, 37, 40] (당첨금: -1000원)
# random_forest               : [6, 12, 20, 24, 31, 36] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 7, 8, 11, 41] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# LSTM                        : [7, 13, 14, 19, 34, 40] (당첨금: -1000원)
# Bayesian                    : [1, 11, 19, 21, 38, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 9, 16, 24, 35, 40] (당첨금: -1000원)
# MarkovChain                 : [38, 39, 40, 41, 42, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (4주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [8, 15, 19, 21, 32, 36]
# total_high_frequency        : [6, 12, 16, 18, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [5, 6, 12, 19, 25, 32] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 16, 18, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 19, 25, 32, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 16, 18, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 27, 32] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [9, 17, 21, 27, 35, 40] (당첨금: -1000원)
# random_forest               : [9, 17, 24, 29, 35, 40] (당첨금: -1000원)
# gradient_boosting           : [5, 11, 12, 21, 27, 35] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# LSTM                        : [6, 7, 12, 13, 32, 38] (당첨금: -1000원)
# Bayesian                    : [6, 12, 21, 28, 33, 38] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [3, 8, 14, 23, 31, 34] (당첨금: -1000원)
# MarkovChain                 : [23, 24, 26, 27, 28, 32] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (3주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [8, 9, 18, 35, 39, 45]
# total_high_frequency        : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# neural_network              : [6, 12, 20, 22, 35, 38] (당첨금: -1000원)
# random_forest               : [6, 15, 20, 26, 32, 40] (당첨금: -1000원)
# gradient_boosting           : [5, 7, 10, 16, 27, 33] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# LSTM                        : [6, 13, 18, 32, 33, 40] (당첨금: -1000원)
# Bayesian                    : [6, 13, 21, 36, 38, 45] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 15, 15, 36, 42] (당첨금: -1000원)
# MarkovChain                 : [1, 3, 37, 38, 39, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (2주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [2, 3, 9, 15, 27, 29]
# total_high_frequency        : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [5, 8, 22, 27, 37, 41] (당첨금: -1000원)
# random_forest               : [8, 13, 21, 27, 36, 41] (당첨금: -1000원)
# gradient_boosting           : [6, 11, 12, 22, 30, 36] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# LSTM                        : [7, 13, 20, 26, 32, 39] (당첨금: -1000원)
# Bayesian                    : [16, 21, 30, 33, 42, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 3, 24, 26, 38, 39] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (1주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [30, 31, 32, 35, 36, 37]
# total_high_frequency        : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [6, 7, 12, 19, 25, 32] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [3, 6, 12, 19, 25, 32] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 9, 12, 19, 25, 32] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [5, 16, 24, 25, 32, 38] (당첨금: -1000원)
# random_forest               : [8, 14, 21, 28, 34, 41] (당첨금: -1000원)
# gradient_boosting           : [8, 10, 18, 22, 27, 41] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# LSTM                        : [7, 14, 20, 27, 33, 40] (당첨금: -1000원)
# Bayesian                    : [6, 9, 12, 16, 19, 33] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: 4000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 7, 28, 29, 30, 36] (당첨금: -1000원)
# MarkovChain                 : [30, 31, 33, 34, 38, 40] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###
# total_high_frequency        : 총 당첨 -47000원(1회)
# total_low_frequency         : 총 당첨 -47000원(1회)
# total_combined_frequency    : 총 당첨 -47000원(1회)
# total_next_vector           : 총 당첨 -47000원(1회)
# recent_52_high_frequency    : 총 당첨 -47000원(1회)
# recent_52_low_frequency     : 총 당첨 -47000원(1회)
# recent_52_combined_frequency: 총 당첨 -47000원(1회)
# recent_52_next_vector       : 총 당첨 -47000원(1회)
# recent_26_high_frequency    : 총 당첨 -47000원(1회)
# recent_26_low_frequency     : 총 당첨 -47000원(1회)
# recent_26_combined_frequency: 총 당첨 -47000원(1회)
# recent_26_next_vector       : 총 당첨 -47000원(1회)
# neural_network              : 총 당첨 -37000원(3회)
# random_forest               : 총 당첨 -52000원(0회)
# gradient_boosting           : 총 당첨 -47000원(1회)
# LSTM                        : 총 당첨 -47000원(1회)
# Bayesian                    : 총 당첨 -32000원(4회)
# KMeans                      : 총 당첨 -42000원(2회)
# AutoEncoder                 : 총 당첨 -47000원(1회)
# MarkovChain                 : 총 당첨 -52000원(0회)
# Ensemble: 총 당첨 -47000원(1회)
#
# ### 다음 주 예상 번호 ###
# total_high_frequency        : [12, 16, 18, 19, 21, 33]
# total_low_frequency         : [5, 9, 20, 23, 25, 32]
# total_combined_frequency    : [5, 12, 20, 21, 25, 33]
# total_next_vector           : [9, 18, 24, 31, 37, 44]
# recent_52_high_frequency    : [12, 16, 18, 19, 21, 33]
# recent_52_low_frequency     : [5, 9, 20, 23, 25, 32]
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33]
# recent_52_next_vector       : [10, 18, 24, 31, 37, 44]
# recent_26_high_frequency    : [12, 16, 18, 19, 21, 33]
# recent_26_low_frequency     : [5, 9, 20, 23, 25, 32]
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33]
# recent_26_next_vector       : [18, 24, 31, 33, 37, 44]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# neural_network              : [4, 8, 19, 29, 34, 42]
# random_forest               : [5, 12, 17, 23, 31, 38]
# gradient_boosting           : [1, 6, 7, 10, 15, 31]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# LSTM                        : [6, 13, 19, 26, 33, 40]
# Bayesian                    : [6, 7, 18, 19, 21, 45]
# KMeans                      : [11, 12, 13, 16, 18, 19]
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 10, 12, 22, 33, 44]
# MarkovChain                 : [38, 39, 40, 41, 42, 45]
#
# Ensemble                    : [5, 12, 18, 19, 21, 33]

# %%
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
import numpy as np
from skopt import gp_minimize
from skopt.space import Integer

# 번호의 중복 제거 및 부족 시 채워주는 함수
def ensure_unique_numbers(numbers):
    numbers = list(set(numbers))  # 중복 제거
    while len(numbers) < 6:
        numbers.append(random.randint(1, 45))  # 부족한 번호를 무작위로 추가
    return sorted(numbers[:6])

# 실제 번호와 예측 번호를 비교하여 보상을 계산하는 함수
def calculate_rewards(actual, predicted):
    match_count = len(set(actual) & set(predicted))  # 일치하는 번호 개수 계산
    rewards = {6: 10_000_000_000, 5: 1_499_000, 4: 49_000, 3: 4_000}
    return rewards.get(match_count, -1_000)  # 일치하지 않으면 -1,000 반환

# 앙상블 예측 함수
def predict_ensemble_from_numpy(predictions_list):
    """
    각 모델의 예측값을 numpy array로 받아 앙상블 예측 수행.
    """
    flat_predictions = np.concatenate(predictions_list).flatten()
    flat_predictions = flat_predictions[(flat_predictions >= 1) & (flat_predictions <= 45)]  # 유효 번호 필터링
    frequency_counts = pd.Series(flat_predictions).value_counts()

    if frequency_counts.empty:
        print("빈도 계산 결과가 없습니다. 빈 결과를 반환합니다.")
        return []

    return ensure_unique_numbers(frequency_counts.nlargest(6).index.tolist())

# 예측 모델의 성능을 평가하는 함수
def evaluate_predictions(data, prediction_functions, weeks_to_evaluate=52):
    total_rewards = {method: {"total_reward": 0, "win_count": 0} for method in prediction_functions.keys()}
    total_rewards["Ensemble"] = {"total_reward": 0, "win_count": 0}  # 앙상블 결과 추가
    prediction_storage = {method: [] for method in prediction_functions.keys()}

    for weeks_ago in range(weeks_to_evaluate, 0, -1):
        train_data = data[:-weeks_ago]
        test_data = data.iloc[-weeks_ago].values[2:]

        print(f"\n### ({weeks_ago}주전)예측되는 번호와 당첨 금액 ###")
        print(f"=> 실제 당첨 번호           : {sorted(test_data)}")

        for method, func in prediction_functions.items():
            predicted = func(train_data, weeks_ago)
            predicted = ensure_unique_numbers(predicted)

            if not predicted:
                print(f"{method}의 예측 결과가 비어 있습니다.")
                continue

            prediction_storage[method].append(predicted)  # 숫자 리스트 저장
            reward = calculate_rewards(test_data, predicted)
            total_rewards[method]["total_reward"] += reward
            if reward > 0:
                total_rewards[method]["win_count"] += 1

            print(f"{method}: {sorted(predicted)} (당첨금: {reward}원)")

        # 앙상블 예측 수행
        ensemble_predictions = predict_ensemble_from_numpy(
            [np.array(prediction_storage[method]) for method in prediction_storage]
        )
        ensemble_reward = calculate_rewards(test_data, ensemble_predictions)
        total_rewards["Ensemble"]["total_reward"] += ensemble_reward
        if ensemble_reward > 0:
            total_rewards["Ensemble"]["win_count"] += 1

        print(f"Ensemble                    : {ensemble_predictions} (당첨금: {ensemble_reward}원)")

    return total_rewards

# 높은 빈도의 숫자를 기반으로 예측
def predict_high_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nlargest(6).index.tolist()  # 상위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 낮은 빈도의 숫자를 기반으로 예측
def predict_low_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nsmallest(6).index.tolist()  # 하위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 높은 빈도 3개 + 낮은 빈도 3개 조합으로 예측
def predict_combined_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    most_frequent = frequency_counts.nlargest(3).index.tolist()  # 상위 3개 숫자
    least_frequent = frequency_counts.nsmallest(3).index.tolist()  # 하위 3개 숫자
    return ensure_unique_numbers(most_frequent + least_frequent)

# PCA를 사용하여 다음 벡터를 예측
def predict_next_vector(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(numbers)  # 데이터 스케일링

    pca = PCA(n_components=1)
    principal_component = pca.fit_transform(scaled_data)  # PCA 변환

    next_vector = principal_component[-1] + (principal_component[-1] - principal_component[-2])  # 다음 벡터 예측
    inverse_scaled_vector = scaler.inverse_transform(scaled_data.mean(axis=0).reshape(1, -1)) + next_vector

    predicted_numbers = [int(round(num)) for num in inverse_scaled_vector[0] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# 신경망을 사용하여 번호를 예측
def predict_neural_network(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(6, activation='sigmoid')  # Using sigmoid to restrict range
    ])

    model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mae'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])

    # Add random noise (jitter) to each prediction
    jittered_predictions = predictions + np.random.uniform(-0.05, 0.05, size=predictions.shape)
    jittered_predictions = np.clip(jittered_predictions, 0, 1)  # Ensure valid range for sigmoid outputs

    # Inverse transform to original scale
    inverse_transformed = scaler_y.inverse_transform(jittered_predictions)

    # Convert to integers and ensure range
    rounded_numbers = [int(round(num)) for num in inverse_transformed.flatten() if 1 <= round(num) <= 45]
    return ensure_unique_numbers(rounded_numbers[:6])

# 랜덤 포레스트를 사용하여 번호를 예측
def predict_random_forest(data, weeks_ago):
    from sklearn.ensemble import RandomForestRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# Gradient Boosting을 사용하여 번호를 예측
def predict_gradient_boosting(data, weeks_ago):
    from sklearn.ensemble import GradientBoostingRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    y_train = y_train.iloc[:, 0].values
    y_test = y_test.iloc[:, 0].values

    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# LSTM을 사용하여 번호를 예측
def predict_lstm(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(numbers)

    X, y = [], []
    for i in range(len(scaled_data) - 10):
        X.append(scaled_data[i:i + 10])
        y.append(scaled_data[i + 10])

    X, y = np.array(X), np.array(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(128, return_sequences=True),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(6, activation='linear')
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])
    predicted_numbers = scaler.inverse_transform(predictions).flatten()
    return ensure_unique_numbers([int(round(num)) for num in predicted_numbers if 1 <= round(num) <= 45])

# Bayesian Optimization을 사용하여 번호를 예측
def predict_bayesian(data, weeks_ago):
    numbers = data.iloc[:, 2:].values

    def objective_function(x):
        selected_numbers = x
        count = sum(num in selected_numbers for num in numbers.flatten())
        return -count

    search_space = [Integer(1, 45) for _ in range(6)]
    result = gp_minimize(objective_function, search_space, n_calls=100)
    return ensure_unique_numbers(result.x)

# K-평균 클러스터링을 사용하여 번호를 예측
def predict_kmeans_clustering(data, weeks_ago, n_clusters=5):
    numbers = data.iloc[:, 2:].values.flatten().reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(numbers)

    # 가장 빈번한 클러스터 선택
    cluster_counts = pd.Series(kmeans.labels_).value_counts()
    top_cluster = cluster_counts.idxmax()
    top_numbers = numbers[kmeans.labels_ == top_cluster]

    # 상위 6개의 번호 선택
    predicted_numbers = pd.Series(top_numbers.flatten()).value_counts().nlargest(6).index.tolist()
    return ensure_unique_numbers(predicted_numbers)

# 오토인코더를 사용하여 번호를 예측
def predict_autoencoder(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(numbers)

    # 오토인코더 정의
    input_dim = scaled_data.shape[1]
    autoencoder = Sequential([
        Input(shape=(input_dim,)),
        Dense(16, activation='relu'),
        Dense(input_dim, activation='sigmoid')
    ])
    autoencoder.compile(optimizer='adam', loss='mse')
    autoencoder.fit(scaled_data, scaled_data, epochs=50, batch_size=16, verbose=0)

    # 복원된 데이터로 패턴 분석
    decoded_data = autoencoder.predict(scaled_data)
    predicted_numbers = [int(round(num)) for num in decoded_data[-1] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# Markov Chain을 사용하여 번호를 예측
def predict_markov_chain(data, weeks_ago):
    numbers = data.iloc[:, 2:].values.flatten()
    transitions = pd.crosstab(numbers[:-1], numbers[1:])
    probabilities = transitions.div(transitions.sum(axis=1), axis=0)

    last_number = numbers[-1]
    if last_number in probabilities.index:
        next_numbers = probabilities.loc[last_number].nlargest(6).index.tolist()
    else:
        next_numbers = random.sample(range(1, 46), 6)  # 기본값으로 랜덤 샘플 제공

    return ensure_unique_numbers(next_numbers)

# 메인 함수
def main():
    try:
        file_path = "Loto_number.xlsx"  # 엑셀 파일 경로
        data = pd.read_excel(file_path)
    except Exception as e:
        print(f"데이터 로드 실패: {e}")
        return

    # 예측 함수 매핑
    prediction_functions = {
        "total_high_frequency        ": predict_high_frequency_numbers,
        "total_low_frequency         ": predict_low_frequency_numbers,
        "total_combined_frequency    ": predict_combined_frequency_numbers,
        "total_next_vector           ": predict_next_vector,

        "recent_52_high_frequency    ": predict_high_frequency_numbers,
        "recent_52_low_frequency     ": predict_low_frequency_numbers,
        "recent_52_combined_frequency": predict_combined_frequency_numbers,
        "recent_52_next_vector       ": predict_next_vector,

        "recent_26_high_frequency    ": predict_high_frequency_numbers,
        "recent_26_low_frequency     ": predict_low_frequency_numbers,
        "recent_26_combined_frequency": predict_combined_frequency_numbers,
        "recent_26_next_vector       ": predict_next_vector,

        "neural_network              ": predict_neural_network,
        "random_forest               ": predict_random_forest,
        "gradient_boosting           ": predict_gradient_boosting,
        "LSTM                        ": predict_lstm,
        "Bayesian                    ": predict_bayesian,
        "KMeans                      ": predict_kmeans_clustering,
        "AutoEncoder                 ": predict_autoencoder,
        "MarkovChain                 ": predict_markov_chain
    }

    # 모델 성능 평가
    total_rewards = evaluate_predictions(data, prediction_functions)

    print("\n### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###")
    for method, stats in total_rewards.items():
        total_reward = stats["total_reward"]
        win_count = stats["win_count"]
        print(f"{method}: 총 당첨 {total_reward}원({win_count}회)")
           
    print("\n### 다음 주 예상 번호 ###")
    all_predictions = []  # 모든 예측 결과를 저장할 리스트
    for method, func in prediction_functions.items():
        try:
            predicted = func(data, weeks_ago=1)
            predicted = ensure_unique_numbers(predicted)
            all_predictions.append(predicted)  # 앙상블에 포함할 결과 저장
            print(f"{method}: {predicted}")
        except Exception as e:
            print(f"{method}: 예측 실패 (오류: {e})")

    # 앙상블 예측 수행
    if all_predictions:
        ensemble_predictions = predict_ensemble_from_numpy([np.array(pred) for pred in all_predictions])
        print(f"\nEnsemble                    : {ensemble_predictions}")

if __name__ == "__main__":
    main()
# Out:
# ### (52주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 7, 13, 28, 36, 42]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# neural_network              : [7, 12, 24, 27, 34, 39] (당첨금: -1000원)
# random_forest               : [6, 15, 20, 27, 34, 38] (당첨금: -1000원)
# gradient_boosting           : [3, 4, 6, 7, 10, 38] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# LSTM                        : [6, 32, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [16, 18, 19, 21, 22, 24] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 5, 16, 18, 41, 45] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 6, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 16, 18, 20, 21] (당첨금: -1000원)
#
# ### (51주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [13, 14, 22, 26, 37, 38]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# neural_network              : [7, 12, 22, 31, 34, 41] (당첨금: -1000원)
# random_forest               : [7, 15, 22, 28, 34, 41] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 8, 16, 40] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# LSTM                        : [7, 8, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [12, 27, 33, 36, 43, 45] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 4, 9, 32, 36, 44] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 5, 7, 43, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (50주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 12, 29, 31, 40, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [7, 15, 19, 27, 34, 38] (당첨금: -1000원)
# random_forest               : [6, 13, 21, 25, 32, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 7, 8, 10, 27, 41] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# LSTM                        : [5, 6, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [3, 18, 26, 33, 43, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AutoEncoder                 : [1, 9, 15, 21, 39, 41] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (49주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 7, 21, 30, 35, 38]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [10, 12, 19, 21, 35, 38] (당첨금: 4000원)
# random_forest               : [9, 13, 20, 26, 33, 41] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 8, 9, 12] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# LSTM                        : [7, 13, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [6, 18, 38, 42, 43, 45] (당첨금: -1000원)
# KMeans                      : [2, 3, 6, 7, 11, 12] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 7, 36, 37, 44] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (48주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 16, 34, 37, 39, 40]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# neural_network              : [3, 10, 14, 20, 37, 43] (당첨금: -1000원)
# random_forest               : [6, 13, 21, 26, 35, 39] (당첨금: -1000원)
# gradient_boosting           : [2, 6, 7, 9, 10, 15] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step
# LSTM                        : [6, 12, 32, 33, 39, 40] (당첨금: 4000원)
# Bayesian                    : [12, 18, 34, 39, 43, 44] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 9, 11, 23, 28, 34] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (47주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 3, 4, 29, 42, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [8, 16, 21, 27, 36, 41] (당첨금: -1000원)
# random_forest               : [8, 14, 22, 28, 33, 39] (당첨금: -1000원)
# gradient_boosting           : [2, 4, 5, 8, 13, 26] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# LSTM                        : [6, 7, 11, 19, 33, 39] (당첨금: -1000원)
# Bayesian                    : [7, 12, 18, 21, 30, 35] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 12, 18, 20, 22] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (46주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 14, 30, 31, 40, 41]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# neural_network              : [6, 13, 14, 27, 31, 38] (당첨금: 4000원)
# random_forest               : [6, 11, 20, 24, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [4, 7, 14, 18, 37, 41] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# LSTM                        : [7, 8, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [13, 14, 18, 21, 38, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 14, 22, 30, 35, 38] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (45주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 19, 26, 37, 39, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [5, 13, 24, 27, 34, 40] (당첨금: -1000원)
# random_forest               : [8, 16, 21, 28, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 7, 8, 14, 16, 24] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step
# LSTM                        : [6, 7, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [10, 13, 21, 27, 33, 38] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 3, 7, 10, 43] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (44주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 12, 13, 19, 33, 40]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [6, 15, 20, 28, 36, 40] (당첨금: -1000원)
# random_forest               : [8, 16, 21, 31, 36, 40] (당첨금: -1000원)
# gradient_boosting           : [2, 6, 7, 8, 9, 21] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# LSTM                        : [8, 9, 12, 32, 39, 40] (당첨금: -1000원)
# Bayesian                    : [10, 12, 18, 21, 38, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 10, 23, 39, 45] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (43주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 7, 11, 20, 22, 41]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# neural_network              : [8, 12, 19, 25, 34, 37] (당첨금: -1000원)
# random_forest               : [9, 14, 22, 30, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 7, 9, 11] (당첨금: 4000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# LSTM                        : [7, 13, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [18, 19, 38, 42, 43, 45] (당첨금: -1000원)
# KMeans                      : [3, 6, 7, 11, 12, 13] (당첨금: 4000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 11, 15, 25, 30, 35] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (42주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 13, 30, 33, 43, 45]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# neural_network              : [7, 11, 14, 22, 27, 41] (당첨금: -1000원)
# random_forest               : [4, 11, 19, 24, 29, 38] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 10, 26, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# LSTM                        : [6, 7, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [12, 18, 21, 39, 43, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 12, 30, 35, 39, 42] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (41주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [16, 20, 26, 36, 42, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# total_next_vector           : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# neural_network              : [5, 14, 20, 25, 35, 40] (당첨금: -1000원)
# random_forest               : [9, 16, 22, 29, 35, 41] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 30, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# LSTM                        : [7, 13, 14, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [3, 12, 13, 21, 33, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 2, 11, 25, 30, 39] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (40주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [11, 13, 20, 21, 32, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# neural_network              : [9, 14, 15, 26, 38, 40] (당첨금: -1000원)
# random_forest               : [5, 13, 21, 28, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [1, 1, 5, 6, 7, 27] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step
# LSTM                        : [7, 13, 14, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [12, 16, 18, 19, 43, 45] (당첨금: -1000원)
# KMeans                      : [2, 3, 6, 7, 11, 12] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# AutoEncoder                 : [1, 14, 16, 25, 34, 41] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: 4000원)
#
# ### (39주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 16, 19, 32, 33, 38]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# total_next_vector           : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# recent_52_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# recent_26_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# neural_network              : [6, 11, 18, 26, 36, 43] (당첨금: -1000원)
# random_forest               : [7, 14, 20, 26, 35, 41] (당첨금: -1000원)
# gradient_boosting           : [3, 4, 5, 6, 23, 39] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# LSTM                        : [6, 12, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [1, 10, 12, 16, 18, 45] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 5, 20, 27, 39, 45] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (38주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 12, 23, 32, 34, 36]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# total_next_vector           : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# neural_network              : [4, 13, 19, 25, 30, 36] (당첨금: -1000원)
# random_forest               : [6, 12, 21, 27, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 15, 22, 38] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# LSTM                        : [6, 7, 12, 32, 33, 39] (당첨금: 4000원)
# Bayesian                    : [10, 13, 16, 18, 34, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 14, 16, 18] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 16, 30, 36, 41] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (37주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [15, 16, 17, 25, 30, 31]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# total_next_vector           : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [11, 17, 20, 27, 32, 34] (당첨금: -1000원)
# random_forest               : [6, 13, 18, 24, 31, 38] (당첨금: -1000원)
# gradient_boosting           : [2, 3, 4, 5, 7, 9] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# LSTM                        : [6, 7, 13, 19, 33, 39] (당첨금: -1000원)
# Bayesian                    : [10, 12, 13, 18, 21, 34] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 5, 9, 27, 37, 38] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (36주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 4, 9, 30, 33, 36]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [6, 11, 22, 27, 34, 38] (당첨금: -1000원)
# random_forest               : [9, 15, 20, 27, 34, 38] (당첨금: -1000원)
# gradient_boosting           : [2, 3, 5, 6, 7, 8] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# LSTM                        : [7, 13, 14, 34, 35, 41] (당첨금: -1000원)
# Bayesian                    : [11, 16, 21, 24, 33, 44] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 7, 11, 13, 28, 35] (당첨금: -1000원)
# MarkovChain                 : [32, 33, 34, 35, 36, 39] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (35주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [11, 13, 14, 15, 16, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# neural_network              : [3, 9, 20, 26, 41, 42] (당첨금: -1000원)
# random_forest               : [7, 14, 19, 27, 34, 42] (당첨금: -1000원)
# gradient_boosting           : [2, 3, 5, 7, 8, 30] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# LSTM                        : [7, 15, 20, 26, 32, 40] (당첨금: -1000원)
# Bayesian                    : [12, 16, 19, 30, 35, 45] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 4, 10, 10, 26, 40] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (34주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 9, 12, 13, 20, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# total_next_vector           : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# recent_52_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# recent_26_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# neural_network              : [5, 13, 20, 22, 38, 42] (당첨금: -1000원)
# random_forest               : [7, 12, 20, 26, 35, 42] (당첨금: -1000원)
# gradient_boosting           : [3, 6, 7, 8, 36, 40] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# LSTM                        : [7, 13, 14, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [11, 31, 33, 34, 38, 43] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 4, 5, 17, 30, 35] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (33주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [2, 19, 26, 31, 38, 41]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [9, 13, 22, 23, 34, 39] (당첨금: -1000원)
# random_forest               : [7, 15, 18, 26, 31, 38] (당첨금: 4000원)
# gradient_boosting           : [3, 4, 5, 6, 7, 8] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# LSTM                        : [6, 13, 14, 21, 33, 40] (당첨금: -1000원)
# Bayesian                    : [7, 19, 38, 39, 43, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 14, 16, 18] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 10, 20, 22, 38, 43] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (32주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 24, 31, 32, 38, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# neural_network              : [7, 15, 22, 28, 34, 40] (당첨금: -1000원)
# random_forest               : [9, 15, 20, 26, 34, 38] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 8, 27, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# LSTM                        : [6, 7, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [11, 12, 21, 31, 39, 45] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 8, 32, 36, 40, 43] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (31주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 6, 21, 30, 34, 35]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# neural_network              : [4, 10, 18, 29, 31, 41] (당첨금: -1000원)
# random_forest               : [5, 12, 18, 26, 33, 39] (당첨금: -1000원)
# gradient_boosting           : [5, 7, 9, 17, 22, 31] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# LSTM                        : [6, 12, 13, 19, 33, 40] (당첨금: -1000원)
# Bayesian                    : [4, 7, 18, 19, 33, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 27, 29, 30, 32, 43] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (30주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [13, 19, 21, 24, 34, 35]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# neural_network              : [6, 10, 21, 30, 35, 41] (당첨금: -1000원)
# random_forest               : [6, 14, 20, 26, 33, 40] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 7, 8, 10, 15] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# LSTM                        : [7, 14, 34, 35, 40, 41] (당첨금: -1000원)
# Bayesian                    : [12, 21, 33, 42, 44, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 5, 7, 12, 34] (당첨금: -1000원)
# MarkovChain                 : [36, 37, 38, 39, 42, 43] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (29주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 8, 17, 30, 33, 34]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# total_next_vector           : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# recent_52_next_vector       : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# recent_26_next_vector       : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# neural_network              : [8, 15, 21, 24, 36, 40] (당첨금: -1000원)
# random_forest               : [8, 14, 21, 27, 36, 41] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 7, 10, 15, 18] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# LSTM                        : [6, 13, 14, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [16, 21, 32, 33, 34, 38] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 12, 17, 18, 26, 42] (당첨금: -1000원)
# MarkovChain                 : [36, 37, 38, 39, 42, 43] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (28주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 14, 25, 33, 40, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [5, 13, 15, 26, 28, 37] (당첨금: -1000원)
# random_forest               : [7, 14, 19, 27, 34, 41] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 7, 8, 9] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# LSTM                        : [6, 7, 12, 13, 34, 39] (당첨금: -1000원)
# Bayesian                    : [6, 13, 21, 34, 44, 45] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 11, 20, 32, 36] (당첨금: -1000원)
# MarkovChain                 : [35, 36, 37, 38, 39, 42] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (27주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [4, 5, 9, 11, 37, 40]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# neural_network              : [6, 10, 23, 26, 39, 41] (당첨금: -1000원)
# random_forest               : [6, 12, 20, 24, 31, 40] (당첨금: -1000원)
# gradient_boosting           : [3, 4, 5, 7, 10, 12] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# LSTM                        : [7, 13, 33, 34, 40, 41] (당첨금: -1000원)
# Bayesian                    : [3, 7, 18, 21, 33, 39] (당첨금: -1000원)
# KMeans                      : [30, 31, 33, 34, 35, 36] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 28, 38, 42, 44] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (26주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 15, 24, 30, 31, 37]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [5, 19, 20, 30, 32, 36] (당첨금: -1000원)
# random_forest               : [6, 12, 18, 25, 33, 41] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 10, 11, 27] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# LSTM                        : [6, 13, 19, 32, 38, 39] (당첨금: -1000원)
# Bayesian                    : [3, 19, 21, 30, 34, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 10, 25, 28, 29] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (25주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 5, 8, 16, 28, 33]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [5, 11, 19, 23, 33, 40] (당첨금: -1000원)
# random_forest               : [7, 12, 18, 24, 31, 40] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 8, 13, 24] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# LSTM                        : [7, 8, 12, 33, 34, 39] (당첨금: -1000원)
# Bayesian                    : [3, 6, 33, 38, 39, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 11, 30, 35, 37] (당첨금: -1000원)
# MarkovChain                 : [38, 39, 40, 41, 42, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (24주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [5, 10, 11, 17, 28, 34]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [7, 13, 20, 26, 32, 33] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [7, 13, 20, 26, 33, 34] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [7, 12, 15, 30, 32, 42] (당첨금: -1000원)
# random_forest               : [7, 13, 18, 25, 34, 41] (당첨금: -1000원)
# gradient_boosting           : [6, 7, 9, 14, 32, 35] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# LSTM                        : [7, 13, 14, 20, 33, 39] (당첨금: -1000원)
# Bayesian                    : [6, 16, 18, 24, 44, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 8, 16, 24, 31] (당첨금: -1000원)
# MarkovChain                 : [34, 35, 36, 37, 38, 40] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (23주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [15, 19, 21, 25, 27, 28]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 32, 38] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 19, 25, 32, 38] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 32, 38] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# neural_network              : [5, 10, 18, 29, 31, 39] (당첨금: -1000원)
# random_forest               : [5, 11, 21, 27, 33, 40] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 8, 9, 10] (당첨금: -1000원)
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# neural_network              : [5, 11, 16, 26, 36, 42] (당첨금: -1000원)
# random_forest               : [7, 14, 20, 28, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 8, 9, 10, 38] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# LSTM                        : [6, 12, 19, 32, 38, 39] (당첨금: -1000원)
# Bayesian                    : [3, 16, 18, 31, 33, 38] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 7, 15, 40, 44, 45] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (8주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [2, 11, 31, 33, 37, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [2, 8, 15, 21, 28, 34] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [2, 8, 15, 21, 28, 34] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [2, 8, 15, 21, 28, 34] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# neural_network              : [8, 14, 18, 29, 36, 41] (당첨금: -1000원)
# random_forest               : [6, 14, 18, 24, 31, 38] (당첨금: -1000원)
# gradient_boosting           : [6, 7, 8, 9, 29, 38] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# LSTM                        : [6, 12, 13, 19, 32, 39] (당첨금: -1000원)
# Bayesian                    : [14, 18, 21, 27, 33, 38] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step
# AutoEncoder                 : [1, 4, 19, 28, 38, 42] (당첨금: -1000원)
# MarkovChain                 : [35, 36, 37, 38, 39, 42] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (7주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 11, 17, 19, 40, 43]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [12, 18, 25, 31, 38, 45] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [12, 18, 25, 31, 38, 45] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [12, 18, 25, 31, 38, 45] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [5, 16, 18, 30, 35, 39] (당첨금: -1000원)
# random_forest               : [7, 15, 20, 28, 32, 39] (당첨금: -1000원)
# gradient_boosting           : [5, 8, 9, 12, 21, 29] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# LSTM                        : [7, 13, 20, 34, 40, 41] (당첨금: -1000원)
# Bayesian                    : [12, 13, 16, 18, 33, 42] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 13, 32, 36, 39, 45] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (6주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 11, 24, 26, 27, 37]
# total_high_frequency        : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [9, 14, 22, 25, 30, 40] (당첨금: -1000원)
# random_forest               : [7, 13, 20, 28, 32, 41] (당첨금: -1000원)
# gradient_boosting           : [5, 7, 8, 9, 20, 37] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# LSTM                        : [7, 13, 14, 34, 40, 41] (당첨금: -1000원)
# Bayesian                    : [12, 13, 15, 16, 38, 45] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 5, 15, 22, 24, 33] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 6, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (5주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 6, 13, 15, 16, 22]
# total_high_frequency        : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [6, 13, 19, 26, 32, 39] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 13, 19, 26, 32, 39] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 13, 19, 26, 32, 39] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [5, 12, 19, 22, 32, 40] (당첨금: -1000원)
# random_forest               : [5, 13, 20, 24, 31, 39] (당첨금: -1000원)
# gradient_boosting           : [2, 5, 7, 8, 11, 41] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# LSTM                        : [7, 13, 19, 32, 33, 39] (당첨금: -1000원)
# Bayesian                    : [6, 12, 19, 21, 24, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 27, 36, 37, 44] (당첨금: -1000원)
# MarkovChain                 : [38, 39, 40, 41, 42, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (4주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [8, 15, 19, 21, 32, 36]
# total_high_frequency        : [6, 12, 16, 18, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 28, 32] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 16, 18, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [5, 6, 12, 19, 25, 32] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 16, 18, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 32, 41] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [4, 8, 14, 26, 35, 39] (당첨금: -1000원)
# random_forest               : [9, 16, 21, 28, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [1, 3, 5, 11, 31, 45] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# LSTM                        : [7, 13, 20, 27, 33, 40] (당첨금: -1000원)
# Bayesian                    : [13, 14, 21, 33, 38, 43] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [4, 19, 20, 29, 35, 40] (당첨금: -1000원)
# MarkovChain                 : [23, 24, 26, 27, 28, 32] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (3주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [8, 9, 18, 35, 39, 45]
# total_high_frequency        : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [6, 10, 19, 30, 35, 38] (당첨금: -1000원)
# random_forest               : [8, 14, 21, 28, 32, 41] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 14, 25, 42, 45] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# LSTM                        : [6, 7, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [3, 12, 19, 34, 35, 45] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 5, 6, 9, 31, 41] (당첨금: -1000원)
# MarkovChain                 : [1, 3, 37, 38, 39, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (2주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [2, 3, 9, 15, 27, 29]
# total_high_frequency        : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [7, 11, 24, 26, 38, 40] (당첨금: -1000원)
# random_forest               : [7, 13, 20, 29, 33, 42] (당첨금: -1000원)
# gradient_boosting           : [6, 9, 23, 30, 31, 45] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# LSTM                        : [6, 14, 20, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [11, 19, 21, 33, 42, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 4, 7, 26, 27, 30] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (1주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [30, 31, 32, 35, 36, 37]
# total_high_frequency        : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 32, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 19, 25, 30, 32] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 30, 32] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [8, 15, 16, 28, 31, 41] (당첨금: -1000원)
# random_forest               : [9, 15, 19, 27, 33, 40] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 9, 10, 12, 16] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# LSTM                        : [6, 13, 19, 26, 32, 39] (당첨금: -1000원)
# Bayesian                    : [12, 15, 18, 19, 38, 45] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: 4000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 17, 19, 29, 40, 43] (당첨금: -1000원)
# MarkovChain                 : [30, 31, 33, 34, 38, 40] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###
# total_high_frequency        : 총 당첨 -47000원(1회)
# total_low_frequency         : 총 당첨 -47000원(1회)
# total_combined_frequency    : 총 당첨 -47000원(1회)
# total_next_vector           : 총 당첨 -47000원(1회)
# recent_52_high_frequency    : 총 당첨 -47000원(1회)
# recent_52_low_frequency     : 총 당첨 -47000원(1회)
# recent_52_combined_frequency: 총 당첨 -47000원(1회)
# recent_52_next_vector       : 총 당첨 -47000원(1회)
# recent_26_high_frequency    : 총 당첨 -47000원(1회)
# recent_26_low_frequency     : 총 당첨 -47000원(1회)
# recent_26_combined_frequency: 총 당첨 -47000원(1회)
# recent_26_next_vector       : 총 당첨 -47000원(1회)
# neural_network              : 총 당첨 -32000원(4회)
# random_forest               : 총 당첨 -47000원(1회)
# gradient_boosting           : 총 당첨 -47000원(1회)
# LSTM                        : 총 당첨 -37000원(3회)
# Bayesian                    : 총 당첨 -47000원(1회)
# KMeans                      : 총 당첨 -42000원(2회)
# AutoEncoder                 : 총 당첨 -52000원(0회)
# MarkovChain                 : 총 당첨 -52000원(0회)
# Ensemble: 총 당첨 -47000원(1회)
#
# ### 다음 주 예상 번호 ###
# total_high_frequency        : [12, 16, 18, 19, 21, 33]
# total_low_frequency         : [5, 9, 20, 23, 25, 32]
# total_combined_frequency    : [5, 12, 20, 21, 25, 33]
# total_next_vector           : [18, 22, 24, 31, 37, 44]
# recent_52_high_frequency    : [12, 16, 18, 19, 21, 33]
# recent_52_low_frequency     : [5, 9, 20, 23, 25, 32]
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33]
# recent_52_next_vector       : [15, 18, 24, 31, 37, 44]
# recent_26_high_frequency    : [12, 16, 18, 19, 21, 33]
# recent_26_low_frequency     : [5, 9, 20, 23, 25, 32]
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33]
# recent_26_next_vector       : [18, 24, 31, 37, 43, 44]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# neural_network              : [5, 11, 20, 29, 33, 40]
# random_forest               : [6, 12, 17, 25, 33, 39]
# gradient_boosting           : [6, 9, 19, 30, 38, 40]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# LSTM                        : [6, 14, 20, 27, 33, 41]
# Bayesian                    : [12, 18, 31, 34, 44, 45]
# KMeans                      : [11, 12, 13, 16, 18, 19]
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 17, 21, 33, 43, 45]
# MarkovChain                 : [38, 39, 40, 41, 42, 45]
#
# Ensemble                    : [12, 18, 20, 21, 25, 33]

# %%
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
import numpy as np
from skopt import gp_minimize
from skopt.space import Integer

# 번호의 중복 제거 및 부족 시 채워주는 함수
def ensure_unique_numbers(numbers):
    numbers = list(set(numbers))  # 중복 제거
    while len(numbers) < 6:
        numbers.append(random.randint(1, 45))  # 부족한 번호를 무작위로 추가
    return sorted(numbers[:6])

# 실제 번호와 예측 번호를 비교하여 보상을 계산하는 함수
def calculate_rewards(actual, predicted):
    match_count = len(set(actual) & set(predicted))  # 일치하는 번호 개수 계산
    rewards = {6: 10_000_000_000, 5: 1_499_000, 4: 49_000, 3: 4_000}
    return rewards.get(match_count, -1_000)  # 일치하지 않으면 -1,000 반환

# 앙상블 예측 함수
def predict_ensemble_from_numpy(predictions_list):
    """
    각 모델의 예측값을 numpy array로 받아 앙상블 예측 수행.
    """
    flat_predictions = np.concatenate(predictions_list).flatten()
    flat_predictions = flat_predictions[(flat_predictions >= 1) & (flat_predictions <= 45)]  # 유효 번호 필터링
    frequency_counts = pd.Series(flat_predictions).value_counts()

    if frequency_counts.empty:
        print("빈도 계산 결과가 없습니다. 빈 결과를 반환합니다.")
        return []

    return ensure_unique_numbers(frequency_counts.nlargest(6).index.tolist())

# 예측 모델의 성능을 평가하는 함수
def evaluate_predictions(data, prediction_functions, weeks_to_evaluate=52):
    total_rewards = {method: {"total_reward": 0, "win_count": 0} for method in prediction_functions.keys()}
    total_rewards["Ensemble"] = {"total_reward": 0, "win_count": 0}  # 앙상블 결과 추가
    prediction_storage = {method: [] for method in prediction_functions.keys()}

    for weeks_ago in range(weeks_to_evaluate, 0, -1):
        train_data = data[:-weeks_ago]
        test_data = data.iloc[-weeks_ago].values[2:]

        print(f"\n### ({weeks_ago}주전)예측되는 번호와 당첨 금액 ###")
        print(f"=> 실제 당첨 번호           : {sorted(test_data)}")

        for method, func in prediction_functions.items():
            predicted = func(train_data, weeks_ago)
            predicted = ensure_unique_numbers(predicted)

            if not predicted:
                print(f"{method}의 예측 결과가 비어 있습니다.")
                continue

            prediction_storage[method].append(predicted)  # 숫자 리스트 저장
            reward = calculate_rewards(test_data, predicted)
            total_rewards[method]["total_reward"] += reward
            if reward > 0:
                total_rewards[method]["win_count"] += 1

            print(f"{method}: {sorted(predicted)} (당첨금: {reward}원)")

        # 앙상블 예측 수행
        ensemble_predictions = predict_ensemble_from_numpy(
            [np.array(prediction_storage[method]) for method in prediction_storage]
        )
        ensemble_reward = calculate_rewards(test_data, ensemble_predictions)
        total_rewards["Ensemble"]["total_reward"] += ensemble_reward
        if ensemble_reward > 0:
            total_rewards["Ensemble"]["win_count"] += 1

        print(f"Ensemble                    : {ensemble_predictions} (당첨금: {ensemble_reward}원)")

    return total_rewards

# 높은 빈도의 숫자를 기반으로 예측
def predict_high_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nlargest(6).index.tolist()  # 상위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 낮은 빈도의 숫자를 기반으로 예측
def predict_low_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nsmallest(6).index.tolist()  # 하위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 높은 빈도 3개 + 낮은 빈도 3개 조합으로 예측
def predict_combined_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    most_frequent = frequency_counts.nlargest(3).index.tolist()  # 상위 3개 숫자
    least_frequent = frequency_counts.nsmallest(3).index.tolist()  # 하위 3개 숫자
    return ensure_unique_numbers(most_frequent + least_frequent)

# PCA를 사용하여 다음 벡터를 예측
def predict_next_vector(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(numbers)  # 데이터 스케일링

    pca = PCA(n_components=1)
    principal_component = pca.fit_transform(scaled_data)  # PCA 변환

    next_vector = principal_component[-1] + (principal_component[-1] - principal_component[-2])  # 다음 벡터 예측
    inverse_scaled_vector = scaler.inverse_transform(scaled_data.mean(axis=0).reshape(1, -1)) + next_vector

    predicted_numbers = [int(round(num)) for num in inverse_scaled_vector[0] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# 신경망을 사용하여 번호를 예측
def predict_neural_network(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(6, activation='sigmoid')  # Using sigmoid to restrict range
    ])

    model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mae'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])

    # Add random noise (jitter) to each prediction
    jittered_predictions = predictions + np.random.uniform(-0.05, 0.05, size=predictions.shape)
    jittered_predictions = np.clip(jittered_predictions, 0, 1)  # Ensure valid range for sigmoid outputs

    # Inverse transform to original scale
    inverse_transformed = scaler_y.inverse_transform(jittered_predictions)

    # Convert to integers and ensure range
    rounded_numbers = [int(round(num)) for num in inverse_transformed.flatten() if 1 <= round(num) <= 45]
    return ensure_unique_numbers(rounded_numbers[:6])

# 랜덤 포레스트를 사용하여 번호를 예측
def predict_random_forest(data, weeks_ago):
    from sklearn.ensemble import RandomForestRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# Gradient Boosting을 사용하여 번호를 예측
def predict_gradient_boosting(data, weeks_ago):
    from sklearn.ensemble import GradientBoostingRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    y_train = y_train.iloc[:, 0].values
    y_test = y_test.iloc[:, 0].values

    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# LSTM을 사용하여 번호를 예측
def predict_lstm(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(numbers)

    X, y = [], []
    for i in range(len(scaled_data) - 10):
        X.append(scaled_data[i:i + 10])
        y.append(scaled_data[i + 10])

    X, y = np.array(X), np.array(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(128, return_sequences=True),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(6, activation='linear')
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])
    predicted_numbers = scaler.inverse_transform(predictions).flatten()
    return ensure_unique_numbers([int(round(num)) for num in predicted_numbers if 1 <= round(num) <= 45])

# Bayesian Optimization을 사용하여 번호를 예측
def predict_bayesian(data, weeks_ago):
    numbers = data.iloc[:, 2:].values

    def objective_function(x):
        selected_numbers = x
        count = sum(num in selected_numbers for num in numbers.flatten())
        return -count

    search_space = [Integer(1, 45) for _ in range(6)]
    result = gp_minimize(objective_function, search_space, n_calls=100)
    return ensure_unique_numbers(result.x)

# K-평균 클러스터링을 사용하여 번호를 예측
def predict_kmeans_clustering(data, weeks_ago, n_clusters=5):
    numbers = data.iloc[:, 2:].values.flatten().reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(numbers)

    # 가장 빈번한 클러스터 선택
    cluster_counts = pd.Series(kmeans.labels_).value_counts()
    top_cluster = cluster_counts.idxmax()
    top_numbers = numbers[kmeans.labels_ == top_cluster]

    # 상위 6개의 번호 선택
    predicted_numbers = pd.Series(top_numbers.flatten()).value_counts().nlargest(6).index.tolist()
    return ensure_unique_numbers(predicted_numbers)

# 오토인코더를 사용하여 번호를 예측
def predict_autoencoder(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(numbers)

    # 오토인코더 정의
    input_dim = scaled_data.shape[1]
    autoencoder = Sequential([
        Input(shape=(input_dim,)),
        Dense(16, activation='relu'),
        Dense(input_dim, activation='sigmoid')
    ])
    autoencoder.compile(optimizer='adam', loss='mse')
    autoencoder.fit(scaled_data, scaled_data, epochs=50, batch_size=16, verbose=0)

    # 복원된 데이터로 패턴 분석
    decoded_data = autoencoder.predict(scaled_data)
    predicted_numbers = [int(round(num)) for num in decoded_data[-1] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# Markov Chain을 사용하여 번호를 예측
def predict_markov_chain(data, weeks_ago):
    numbers = data.iloc[:, 2:].values.flatten()
    transitions = pd.crosstab(numbers[:-1], numbers[1:])
    probabilities = transitions.div(transitions.sum(axis=1), axis=0)

    last_number = numbers[-1]
    if last_number in probabilities.index:
        next_numbers = probabilities.loc[last_number].nlargest(6).index.tolist()
    else:
        next_numbers = random.sample(range(1, 46), 6)  # 기본값으로 랜덤 샘플 제공

    return ensure_unique_numbers(next_numbers)

# 메인 함수
def main():
    try:
        file_path = "Loto_number.xlsx"  # 엑셀 파일 경로
        data = pd.read_excel(file_path)
    except Exception as e:
        print(f"데이터 로드 실패: {e}")
        return

    # 예측 함수 매핑
    prediction_functions = {
        "total_high_frequency        ": predict_high_frequency_numbers,
        "total_low_frequency         ": predict_low_frequency_numbers,
        "total_combined_frequency    ": predict_combined_frequency_numbers,
        "total_next_vector           ": predict_next_vector,

        "recent_52_high_frequency    ": predict_high_frequency_numbers,
        "recent_52_low_frequency     ": predict_low_frequency_numbers,
        "recent_52_combined_frequency": predict_combined_frequency_numbers,
        "recent_52_next_vector       ": predict_next_vector,

        "recent_26_high_frequency    ": predict_high_frequency_numbers,
        "recent_26_low_frequency     ": predict_low_frequency_numbers,
        "recent_26_combined_frequency": predict_combined_frequency_numbers,
        "recent_26_next_vector       ": predict_next_vector,

        "neural_network              ": predict_neural_network,
        "random_forest               ": predict_random_forest,
        "gradient_boosting           ": predict_gradient_boosting,
        "LSTM                        ": predict_lstm,
        "Bayesian                    ": predict_bayesian,
        "KMeans                      ": predict_kmeans_clustering,
        "AutoEncoder                 ": predict_autoencoder,
        "MarkovChain                 ": predict_markov_chain
    }

    # 모델 성능 평가
    total_rewards = evaluate_predictions(data, prediction_functions)

    print("\n### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###")
    for method, stats in total_rewards.items():
        total_reward = stats["total_reward"]
        win_count = stats["win_count"]
        print(f"{method}: 총 당첨 {total_reward}원({win_count}회)")
           
    print("\n### 다음 주 예상 번호 ###")
    all_predictions = []  # 모든 예측 결과를 저장할 리스트
    for method, func in prediction_functions.items():
        try:
            predicted = func(data, weeks_ago=1)
            predicted = ensure_unique_numbers(predicted)
            all_predictions.append(predicted)  # 앙상블에 포함할 결과 저장
            print(f"{method}: {predicted}")
        except Exception as e:
            print(f"{method}: 예측 실패 (오류: {e})")

    # 앙상블 예측 수행
    if all_predictions:
        ensemble_predictions = predict_ensemble_from_numpy([np.array(pred) for pred in all_predictions])
        print(f"\nEnsemble                    : {ensemble_predictions}")

if __name__ == "__main__":
    main()
# Out:
# ### (52주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 7, 13, 28, 36, 42]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# neural_network              : [5, 11, 12, 28, 32, 39] (당첨금: -1000원)
# random_forest               : [8, 13, 20, 26, 32, 39] (당첨금: -1000원)
# gradient_boosting           : [3, 4, 6, 11, 38, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step
# LSTM                        : [7, 14, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [7, 12, 18, 34, 43, 45] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 30, 34, 37, 40, 45] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 6, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (51주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [13, 14, 22, 26, 37, 38]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [6, 11, 15, 28, 37, 42] (당첨금: -1000원)
# random_forest               : [8, 13, 19, 25, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 7, 8, 21] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# LSTM                        : [7, 13, 32, 33, 38, 39] (당첨금: -1000원)
# Bayesian                    : [6, 12, 18, 33, 34, 45] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 4, 10, 26, 36, 42] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 5, 7, 43, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (50주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 12, 29, 31, 40, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [8, 15, 19, 30, 32, 41] (당첨금: -1000원)
# random_forest               : [7, 13, 22, 26, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [3, 6, 7, 8, 16, 45] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# LSTM                        : [7, 12, 19, 20, 34, 40] (당첨금: -1000원)
# Bayesian                    : [1, 12, 16, 21, 34, 39] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 15, 32, 33, 35, 41] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (49주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 7, 21, 30, 35, 38]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [8, 16, 20, 30, 36, 42] (당첨금: -1000원)
# random_forest               : [8, 13, 21, 29, 34, 41] (당첨금: -1000원)
# gradient_boosting           : [2, 5, 6, 8, 9, 31] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# LSTM                        : [6, 7, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [2, 10, 21, 33, 39, 45] (당첨금: -1000원)
# KMeans                      : [2, 3, 6, 7, 11, 12] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 17, 18, 25, 37, 40] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (48주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 16, 34, 37, 39, 40]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# neural_network              : [5, 9, 16, 26, 35, 42] (당첨금: -1000원)
# random_forest               : [7, 11, 19, 26, 33, 39] (당첨금: -1000원)
# gradient_boosting           : [2, 6, 7, 8, 11, 35] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# LSTM                        : [6, 7, 33, 34, 39, 40] (당첨금: 49000원)
# Bayesian                    : [12, 13, 15, 18, 21, 28] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 9, 11, 16, 17, 27] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (47주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 3, 4, 29, 42, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [8, 12, 23, 27, 35, 43] (당첨금: -1000원)
# random_forest               : [7, 15, 21, 29, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [2, 3, 5, 7, 8, 13] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# LSTM                        : [7, 8, 34, 35, 41, 42] (당첨금: -1000원)
# Bayesian                    : [6, 7, 12, 18, 33, 38] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 17, 18, 21, 34, 36] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (46주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 14, 30, 31, 40, 41]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# neural_network              : [6, 12, 20, 27, 31, 38] (당첨금: -1000원)
# random_forest               : [5, 14, 17, 24, 33, 39] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 7, 14, 21] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step
# LSTM                        : [7, 8, 13, 32, 38, 39] (당첨금: -1000원)
# Bayesian                    : [15, 18, 33, 42, 43, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 16, 20, 39, 40] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (45주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 19, 26, 37, 39, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [9, 15, 22, 23, 37, 39] (당첨금: -1000원)
# random_forest               : [8, 14, 21, 26, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [2, 3, 6, 7, 8, 12] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# LSTM                        : [6, 7, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [11, 14, 18, 21, 34, 39] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 21, 24, 33, 34, 39] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (44주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 12, 13, 19, 33, 40]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [10, 15, 18, 29, 34, 40] (당첨금: -1000원)
# random_forest               : [5, 15, 22, 31, 36, 42] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 8, 37, 40, 43] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# LSTM                        : [6, 13, 14, 32, 33, 40] (당첨금: 4000원)
# Bayesian                    : [11, 13, 18, 38, 39, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 14, 17, 34, 37, 40] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (43주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 7, 11, 20, 22, 41]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# neural_network              : [8, 13, 25, 31, 35, 40] (당첨금: -1000원)
# random_forest               : [8, 14, 21, 30, 36, 39] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 8, 9, 20, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# LSTM                        : [8, 13, 14, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [6, 16, 18, 39, 43, 45] (당첨금: -1000원)
# KMeans                      : [3, 6, 7, 11, 12, 13] (당첨금: 4000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 12, 13, 13, 19, 43] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (42주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 13, 30, 33, 43, 45]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [5, 18, 20, 21, 33, 40] (당첨금: -1000원)
# random_forest               : [5, 11, 18, 23, 30, 38] (당첨금: -1000원)
# gradient_boosting           : [5, 7, 10, 22, 41, 45] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# LSTM                        : [6, 12, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [12, 18, 21, 25, 30, 39] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 12, 24, 29, 37, 42] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (41주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [16, 20, 26, 36, 42, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# total_next_vector           : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [8, 12, 15, 26, 35, 40] (당첨금: -1000원)
# random_forest               : [7, 14, 23, 27, 35, 42] (당첨금: -1000원)
# gradient_boosting           : [3, 4, 5, 6, 9, 11] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# LSTM                        : [6, 7, 13, 20, 35, 40] (당첨금: -1000원)
# Bayesian                    : [7, 12, 21, 33, 34, 43] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 5, 8, 28, 32, 36] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (40주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [11, 13, 20, 21, 32, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [8, 16, 18, 21, 34, 42] (당첨금: -1000원)
# random_forest               : [5, 13, 21, 27, 32, 39] (당첨금: 4000원)
# gradient_boosting           : [4, 5, 6, 7, 13, 23] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# LSTM                        : [7, 13, 33, 34, 38, 39] (당첨금: -1000원)
# Bayesian                    : [6, 7, 13, 16, 18, 38] (당첨금: -1000원)
# KMeans                      : [2, 3, 6, 7, 11, 12] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step
# AutoEncoder                 : [1, 4, 11, 14, 23, 45] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: 4000원)
#
# ### (39주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 16, 19, 32, 33, 38]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# total_next_vector           : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# recent_52_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# recent_26_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [8, 11, 20, 28, 37, 39] (당첨금: -1000원)
# random_forest               : [6, 12, 21, 26, 35, 40] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 15, 17, 35] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# LSTM                        : [6, 7, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [6, 12, 13, 38, 43, 45] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 3, 4, 31, 38] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (38주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 12, 23, 32, 34, 36]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# total_next_vector           : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [6, 10, 17, 30, 37, 39] (당첨금: -1000원)
# random_forest               : [7, 12, 21, 27, 34, 41] (당첨금: 4000원)
# gradient_boosting           : [3, 5, 6, 8, 23, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# LSTM                        : [8, 13, 34, 35, 38, 39] (당첨금: -1000원)
# Bayesian                    : [16, 19, 34, 36, 38, 44] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 14, 16, 18] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 4, 18, 27, 35, 42] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (37주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [15, 16, 17, 25, 30, 31]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# total_next_vector           : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [6, 11, 20, 26, 30, 35] (당첨금: -1000원)
# random_forest               : [6, 13, 18, 24, 33, 39] (당첨금: -1000원)
# gradient_boosting           : [2, 5, 6, 7, 24, 43] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# LSTM                        : [7, 8, 34, 35, 40, 41] (당첨금: -1000원)
# Bayesian                    : [12, 18, 19, 21, 42, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 12, 13, 17, 18, 27] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (36주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 4, 9, 30, 33, 36]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# neural_network              : [8, 19, 21, 24, 27, 39] (당첨금: -1000원)
# random_forest               : [8, 15, 20, 26, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [2, 3, 6, 7, 31, 38] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# LSTM                        : [6, 13, 21, 26, 32, 39] (당첨금: -1000원)
# Bayesian                    : [2, 6, 7, 18, 19, 43] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 19, 26, 30, 39, 43] (당첨금: -1000원)
# MarkovChain                 : [32, 33, 34, 35, 36, 39] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (35주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [11, 13, 14, 15, 16, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [6, 12, 21, 25, 33, 40] (당첨금: -1000원)
# random_forest               : [6, 12, 19, 26, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 8, 24, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step
# LSTM                        : [6, 13, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [12, 13, 21, 31, 33, 45] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 10, 14, 28, 29, 43] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (34주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 9, 12, 13, 20, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# total_next_vector           : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# recent_52_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# recent_26_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# neural_network              : [10, 13, 19, 27, 36, 40] (당첨금: -1000원)
# random_forest               : [7, 14, 20, 26, 32, 40] (당첨금: -1000원)
# gradient_boosting           : [2, 5, 6, 7, 8, 11] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# LSTM                        : [6, 12, 33, 34, 40, 41] (당첨금: -1000원)
# Bayesian                    : [11, 15, 18, 19, 33, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 9, 12, 18, 23, 34] (당첨금: 4000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (33주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [2, 19, 26, 31, 38, 41]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [5, 14, 20, 24, 34, 42] (당첨금: -1000원)
# random_forest               : [5, 13, 19, 25, 32, 39] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 7, 8, 9, 39] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# LSTM                        : [7, 13, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [7, 12, 18, 36, 43, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 14, 16, 18] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 4, 15, 34, 44, 45] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (32주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 24, 31, 32, 38, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# neural_network              : [5, 10, 13, 22, 30, 42] (당첨금: -1000원)
# random_forest               : [8, 14, 22, 26, 33, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 10, 28] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# LSTM                        : [7, 13, 20, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [3, 12, 13, 19, 34, 36] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 4, 12, 28, 30, 36] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (31주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 6, 21, 30, 34, 35]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# neural_network              : [2, 12, 19, 30, 37, 43] (당첨금: -1000원)
# random_forest               : [7, 11, 18, 27, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [1, 5, 6, 7, 8, 31] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# LSTM                        : [6, 13, 33, 34, 40, 41] (당첨금: -1000원)
# Bayesian                    : [7, 12, 13, 16, 18, 43] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 6, 29, 35, 38] (당첨금: 4000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (30주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [13, 19, 21, 24, 34, 35]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [9, 13, 17, 30, 34, 45] (당첨금: -1000원)
# random_forest               : [8, 14, 21, 27, 33, 42] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 8, 9, 10] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# LSTM                        : [7, 12, 13, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [11, 12, 33, 43, 44, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AutoEncoder                 : [1, 8, 26, 27, 28, 42] (당첨금: -1000원)
# MarkovChain                 : [36, 37, 38, 39, 42, 43] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (29주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 8, 17, 30, 33, 34]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# total_next_vector           : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# recent_52_next_vector       : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# recent_26_next_vector       : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# neural_network              : [6, 11, 22, 24, 33, 41] (당첨금: -1000원)
# random_forest               : [8, 12, 21, 29, 34, 41] (당첨금: -1000원)
# gradient_boosting           : [2, 4, 5, 7, 9, 11] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# LSTM                        : [6, 13, 33, 34, 40, 41] (당첨금: -1000원)
# Bayesian                    : [6, 12, 19, 21, 33, 45] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 4, 14, 22, 24, 25] (당첨금: -1000원)
# MarkovChain                 : [36, 37, 38, 39, 42, 43] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (28주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 14, 25, 33, 40, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [8, 11, 14, 23, 30, 37] (당첨금: -1000원)
# random_forest               : [7, 12, 20, 25, 35, 41] (당첨금: -1000원)
# gradient_boosting           : [3, 4, 5, 7, 8, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# LSTM                        : [6, 13, 33, 34, 38, 39] (당첨금: -1000원)
# Bayesian                    : [12, 16, 31, 33, 34, 38] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 20, 30, 37, 38] (당첨금: -1000원)
# MarkovChain                 : [35, 36, 37, 38, 39, 42] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (27주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [4, 5, 9, 11, 37, 40]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# neural_network              : [7, 11, 17, 27, 33, 38] (당첨금: -1000원)
# random_forest               : [5, 10, 17, 23, 33, 40] (당첨금: -1000원)
# gradient_boosting           : [3, 6, 7, 8, 10, 13] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# LSTM                        : [6, 7, 32, 33, 40, 41] (당첨금: -1000원)
# Bayesian                    : [12, 16, 33, 36, 39, 42] (당첨금: -1000원)
# KMeans                      : [30, 31, 33, 34, 35, 36] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 9, 16, 27, 30, 45] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (26주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 15, 24, 30, 31, 37]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [7, 10, 17, 26, 32, 39] (당첨금: -1000원)
# random_forest               : [7, 13, 18, 26, 32, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 7, 8, 10, 13] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# LSTM                        : [6, 12, 13, 34, 40, 41] (당첨금: -1000원)
# Bayesian                    : [7, 11, 16, 33, 34, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 4, 14, 33, 34, 42] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (25주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 5, 8, 16, 28, 33]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [5, 12, 16, 19, 29, 35] (당첨금: -1000원)
# random_forest               : [4, 11, 19, 25, 33, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 9, 12, 21, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# LSTM                        : [6, 11, 12, 19, 25, 39] (당첨금: -1000원)
# Bayesian                    : [10, 18, 21, 33, 39, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 16, 28, 39, 41] (당첨금: 4000원)
# MarkovChain                 : [38, 39, 40, 41, 42, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (24주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [5, 10, 11, 17, 28, 34]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [7, 13, 16, 20, 26, 33] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [7, 13, 20, 26, 33, 35] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [7, 9, 13, 20, 26, 33] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# neural_network              : [6, 9, 14, 22, 30, 38] (당첨금: -1000원)
# random_forest               : [7, 14, 19, 27, 32, 40] (당첨금: -1000원)
# gradient_boosting           : [6, 8, 9, 10, 28, 44] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# LSTM                        : [7, 13, 14, 32, 33, 40] (당첨금: -1000원)
# Bayesian                    : [18, 21, 28, 31, 33, 43] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 8, 20, 26, 39, 42] (당첨금: -1000원)
# MarkovChain                 : [34, 35, 36, 37, 38, 40] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (23주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [15, 19, 21, 25, 27, 28]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 32, 38] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 19, 25, 32, 38] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 32, 38] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [3, 7, 24, 27, 28, 36] (당첨금: -1000원)
# random_forest               : [6, 11, 20, 27, 34, 38] (당첨금: -1000원)
# gradient_boosting           : [1, 5, 6, 7, 9, 10] (당첨금: -1000원)
# ...
# recent_26_next_vector       : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# neural_network              : [7, 18, 21, 27, 37, 43] (당첨금: -1000원)
# random_forest               : [4, 14, 19, 26, 35, 42] (당첨금: -1000원)
# gradient_boosting           : [2, 6, 7, 8, 9, 17] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# LSTM                        : [7, 12, 13, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [12, 16, 19, 21, 35, 41] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 8, 11, 29, 30, 35] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (8주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [2, 11, 31, 33, 37, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [2, 8, 15, 21, 28, 34] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [2, 8, 15, 21, 28, 34] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [2, 8, 15, 21, 28, 34] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# neural_network              : [4, 12, 17, 29, 33, 43] (당첨금: -1000원)
# random_forest               : [5, 11, 18, 23, 30, 39] (당첨금: -1000원)
# gradient_boosting           : [5, 7, 8, 14, 35, 44] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# LSTM                        : [6, 7, 12, 19, 32, 38] (당첨금: -1000원)
# Bayesian                    : [1, 12, 16, 19, 38, 45] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step
# AutoEncoder                 : [1, 7, 8, 9, 17, 33] (당첨금: -1000원)
# MarkovChain                 : [35, 36, 37, 38, 39, 42] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (7주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 11, 17, 19, 40, 43]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [12, 18, 25, 31, 38, 45] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [12, 18, 25, 31, 38, 45] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [12, 18, 25, 31, 38, 45] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# neural_network              : [7, 14, 20, 26, 33, 41] (당첨금: -1000원)
# random_forest               : [7, 14, 20, 28, 34, 41] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 8, 9, 11] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# LSTM                        : [6, 12, 13, 32, 39, 40] (당첨금: -1000원)
# Bayesian                    : [2, 11, 19, 33, 38, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 11, 24, 26, 43] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (6주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 11, 24, 26, 27, 37]
# total_high_frequency        : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [8, 12, 17, 22, 36, 41] (당첨금: -1000원)
# random_forest               : [6, 14, 20, 27, 33, 39] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 7, 9, 24, 32] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# LSTM                        : [7, 13, 20, 27, 34, 39] (당첨금: -1000원)
# Bayesian                    : [6, 7, 12, 30, 36, 38] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 12, 12, 37, 38, 43] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 6, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (5주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 6, 13, 15, 16, 22]
# total_high_frequency        : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [6, 13, 19, 26, 32, 39] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 13, 19, 26, 32, 39] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 13, 19, 26, 32, 39] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [7, 12, 19, 25, 31, 35] (당첨금: -1000원)
# random_forest               : [7, 13, 19, 25, 31, 39] (당첨금: -1000원)
# gradient_boosting           : [2, 5, 7, 8, 10, 19] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# LSTM                        : [7, 13, 20, 32, 39, 40] (당첨금: -1000원)
# Bayesian                    : [12, 14, 16, 34, 38, 43] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 11, 13, 14, 18, 21] (당첨금: -1000원)
# MarkovChain                 : [38, 39, 40, 41, 42, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (4주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [8, 15, 19, 21, 32, 36]
# total_high_frequency        : [6, 12, 16, 18, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 16, 18, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 19, 23, 25, 32] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 16, 18, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 21, 25, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 8, 12, 19, 25, 32] (당첨금: 4000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [7, 16, 19, 30, 33, 40] (당첨금: -1000원)
# random_forest               : [10, 16, 24, 29, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 11, 14, 30] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# LSTM                        : [7, 13, 14, 32, 33, 39] (당첨금: -1000원)
# Bayesian                    : [7, 12, 14, 16, 38, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 17, 36, 39, 42] (당첨금: -1000원)
# MarkovChain                 : [23, 24, 26, 27, 28, 32] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (3주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [8, 9, 18, 35, 39, 45]
# total_high_frequency        : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# neural_network              : [7, 11, 21, 22, 32, 38] (당첨금: -1000원)
# random_forest               : [8, 13, 20, 27, 35, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 7, 19, 21, 26] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# LSTM                        : [7, 14, 21, 32, 38, 39] (당첨금: -1000원)
# Bayesian                    : [21, 31, 33, 38, 41, 45] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 15, 25, 26, 29, 41] (당첨금: -1000원)
# MarkovChain                 : [1, 3, 37, 38, 39, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (2주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [2, 3, 9, 15, 27, 29]
# total_high_frequency        : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [6, 12, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# neural_network              : [6, 11, 22, 30, 37, 40] (당첨금: -1000원)
# random_forest               : [6, 14, 22, 28, 36, 40] (당첨금: -1000원)
# gradient_boosting           : [5, 9, 12, 23, 31, 44] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# LSTM                        : [7, 14, 21, 27, 34, 40] (당첨금: -1000원)
# Bayesian                    : [6, 11, 16, 18, 31, 38] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 7, 21, 34, 38] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (1주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [30, 31, 32, 35, 36, 37]
# total_high_frequency        : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 28, 32] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 15, 19, 25, 32] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 19, 21, 33] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 23, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 32, 42] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# neural_network              : [7, 13, 18, 30, 31, 39] (당첨금: -1000원)
# random_forest               : [7, 15, 19, 25, 33, 38] (당첨금: -1000원)
# gradient_boosting           : [9, 10, 16, 22, 37, 44] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# LSTM                        : [7, 13, 19, 25, 32, 39] (당첨금: -1000원)
# Bayesian                    : [6, 7, 15, 21, 38, 45] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: 4000원)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 15, 16, 18, 23, 45] (당첨금: -1000원)
# MarkovChain                 : [30, 31, 33, 34, 38, 40] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###
# total_high_frequency        : 총 당첨 -47000원(1회)
# total_low_frequency         : 총 당첨 -47000원(1회)
# total_combined_frequency    : 총 당첨 -47000원(1회)
# total_next_vector           : 총 당첨 -47000원(1회)
# recent_52_high_frequency    : 총 당첨 -47000원(1회)
# recent_52_low_frequency     : 총 당첨 -47000원(1회)
# recent_52_combined_frequency: 총 당첨 -47000원(1회)
# recent_52_next_vector       : 총 당첨 -47000원(1회)
# recent_26_high_frequency    : 총 당첨 -47000원(1회)
# recent_26_low_frequency     : 총 당첨 -47000원(1회)
# recent_26_combined_frequency: 총 당첨 -47000원(1회)
# recent_26_next_vector       : 총 당첨 -42000원(2회)
# neural_network              : 총 당첨 -52000원(0회)
# random_forest               : 총 당첨 -42000원(2회)
# gradient_boosting           : 총 당첨 -52000원(0회)
# LSTM                        : 총 당첨 8000원(3회)
# Bayesian                    : 총 당첨 -42000원(2회)
# KMeans                      : 총 당첨 -42000원(2회)
# AutoEncoder                 : 총 당첨 -37000원(3회)
# MarkovChain                 : 총 당첨 -52000원(0회)
# Ensemble: 총 당첨 -47000원(1회)
#
# ### 다음 주 예상 번호 ###
# total_high_frequency        : [12, 16, 18, 19, 21, 33]
# total_low_frequency         : [5, 9, 20, 23, 25, 32]
# total_combined_frequency    : [5, 12, 20, 21, 25, 33]
# total_next_vector           : [3, 18, 24, 31, 37, 44]
# recent_52_high_frequency    : [12, 16, 18, 19, 21, 33]
# recent_52_low_frequency     : [5, 9, 20, 23, 25, 32]
# recent_52_combined_frequency: [5, 12, 20, 21, 25, 33]
# recent_52_next_vector       : [6, 18, 24, 31, 37, 44]
# recent_26_high_frequency    : [12, 16, 18, 19, 21, 33]
# recent_26_low_frequency     : [5, 9, 20, 23, 25, 32]
# recent_26_combined_frequency: [5, 12, 20, 21, 25, 33]
# recent_26_next_vector       : [18, 24, 29, 31, 37, 44]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# neural_network              : [6, 15, 20, 30, 32, 40]
# random_forest               : [7, 12, 17, 24, 33, 39]
# gradient_boosting           : [3, 8, 18, 26, 32, 34]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# LSTM                        : [6, 14, 21, 29, 35, 41]
# Bayesian                    : [12, 18, 21, 33, 42, 45]
# KMeans                      : [11, 12, 13, 16, 18, 19]
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 23, 32, 37, 40, 42]
# MarkovChain                 : [38, 39, 40, 41, 42, 45]
#
# Ensemble                    : [12, 18, 20, 21, 25, 33]

# %%
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
import numpy as np
from skopt import gp_minimize
from skopt.space import Integer

# 번호의 중복 제거 및 부족 시 채워주는 함수
def ensure_unique_numbers(numbers):
    numbers = list(set(numbers))  # 중복 제거
    while len(numbers) < 6:
        numbers.append(random.randint(1, 45))  # 부족한 번호를 무작위로 추가
    return sorted(numbers[:6])

# 실제 번호와 예측 번호를 비교하여 보상을 계산하는 함수
def calculate_rewards(actual, predicted):
    match_count = len(set(actual) & set(predicted))  # 일치하는 번호 개수 계산
    rewards = {6: 10_000_000_000, 5: 1_499_000, 4: 49_000, 3: 4_000}
    return rewards.get(match_count, -1_000)  # 일치하지 않으면 -1,000 반환

# 앙상블 예측 함수
def predict_ensemble_from_numpy(predictions_list):
    """
    각 모델의 예측값을 numpy array로 받아 앙상블 예측 수행.
    """
    flat_predictions = np.concatenate(predictions_list).flatten()
    flat_predictions = flat_predictions[(flat_predictions >= 1) & (flat_predictions <= 45)]  # 유효 번호 필터링
    frequency_counts = pd.Series(flat_predictions).value_counts()

    if frequency_counts.empty:
        print("빈도 계산 결과가 없습니다. 빈 결과를 반환합니다.")
        return []

    return ensure_unique_numbers(frequency_counts.nlargest(6).index.tolist())

# 예측 모델의 성능을 평가하는 함수
def evaluate_predictions(data, prediction_functions, weeks_to_evaluate=52):
    total_rewards = {method: {"total_reward": 0, "win_count": 0} for method in prediction_functions.keys()}
    total_rewards["Ensemble"] = {"total_reward": 0, "win_count": 0}  # 앙상블 결과 추가
    prediction_storage = {method: [] for method in prediction_functions.keys()}

    for weeks_ago in range(weeks_to_evaluate, 0, -1):
        train_data = data[:-weeks_ago]
        test_data = data.iloc[-weeks_ago].values[2:]

        print(f"\n### ({weeks_ago}주전)예측되는 번호와 당첨 금액 ###")
        print(f"=> 실제 당첨 번호           : {sorted(test_data)}")

        for method, func in prediction_functions.items():
            predicted = func(train_data, weeks_ago)
            predicted = ensure_unique_numbers(predicted)

            if not predicted:
                print(f"{method}의 예측 결과가 비어 있습니다.")
                continue

            prediction_storage[method].append(predicted)  # 숫자 리스트 저장
            reward = calculate_rewards(test_data, predicted)
            total_rewards[method]["total_reward"] += reward
            if reward > 0:
                total_rewards[method]["win_count"] += 1

            print(f"{method}: {sorted(predicted)} (당첨금: {reward}원)")

        # 앙상블 예측 수행
        ensemble_predictions = predict_ensemble_from_numpy(
            [np.array(prediction_storage[method]) for method in prediction_storage]
        )
        ensemble_reward = calculate_rewards(test_data, ensemble_predictions)
        total_rewards["Ensemble"]["total_reward"] += ensemble_reward
        if ensemble_reward > 0:
            total_rewards["Ensemble"]["win_count"] += 1

        print(f"Ensemble                    : {ensemble_predictions} (당첨금: {ensemble_reward}원)")

    return total_rewards

# 높은 빈도의 숫자를 기반으로 예측
def predict_high_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nlargest(6).index.tolist()  # 상위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 낮은 빈도의 숫자를 기반으로 예측
def predict_low_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nsmallest(6).index.tolist()  # 하위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 높은 빈도 3개 + 낮은 빈도 3개 조합으로 예측
def predict_combined_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    most_frequent = frequency_counts.nlargest(3).index.tolist()  # 상위 3개 숫자
    least_frequent = frequency_counts.nsmallest(3).index.tolist()  # 하위 3개 숫자
    return ensure_unique_numbers(most_frequent + least_frequent)

# PCA를 사용하여 다음 벡터를 예측
def predict_next_vector(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(numbers)  # 데이터 스케일링

    pca = PCA(n_components=1)
    principal_component = pca.fit_transform(scaled_data)  # PCA 변환

    next_vector = principal_component[-1] + (principal_component[-1] - principal_component[-2])  # 다음 벡터 예측
    inverse_scaled_vector = scaler.inverse_transform(scaled_data.mean(axis=0).reshape(1, -1)) + next_vector

    predicted_numbers = [int(round(num)) for num in inverse_scaled_vector[0] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# 신경망을 사용하여 번호를 예측
def predict_neural_network(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(6, activation='sigmoid')  # Using sigmoid to restrict range
    ])

    model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mae'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])

    # Add random noise (jitter) to each prediction
    jittered_predictions = predictions + np.random.uniform(-0.05, 0.05, size=predictions.shape)
    jittered_predictions = np.clip(jittered_predictions, 0, 1)  # Ensure valid range for sigmoid outputs

    # Inverse transform to original scale
    inverse_transformed = scaler_y.inverse_transform(jittered_predictions)

    # Convert to integers and ensure range
    rounded_numbers = [int(round(num)) for num in inverse_transformed.flatten() if 1 <= round(num) <= 45]
    return ensure_unique_numbers(rounded_numbers[:6])

# 랜덤 포레스트를 사용하여 번호를 예측
def predict_random_forest(data, weeks_ago):
    from sklearn.ensemble import RandomForestRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# Gradient Boosting을 사용하여 번호를 예측
def predict_gradient_boosting(data, weeks_ago):
    from sklearn.ensemble import GradientBoostingRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    y_train = y_train.iloc[:, 0].values
    y_test = y_test.iloc[:, 0].values

    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# LSTM을 사용하여 번호를 예측
def predict_lstm(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(numbers)

    X, y = [], []
    for i in range(len(scaled_data) - 10):
        X.append(scaled_data[i:i + 10])
        y.append(scaled_data[i + 10])

    X, y = np.array(X), np.array(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(128, return_sequences=True),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(6, activation='linear')
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])
    predicted_numbers = scaler.inverse_transform(predictions).flatten()
    return ensure_unique_numbers([int(round(num)) for num in predicted_numbers if 1 <= round(num) <= 45])

# Bayesian Optimization을 사용하여 번호를 예측
def predict_bayesian(data, weeks_ago):
    numbers = data.iloc[:, 2:].values

    def objective_function(x):
        selected_numbers = x
        count = sum(num in selected_numbers for num in numbers.flatten())
        return -count

    search_space = [Integer(1, 45) for _ in range(6)]
    result = gp_minimize(objective_function, search_space, n_calls=100)
    return ensure_unique_numbers(result.x)

# K-평균 클러스터링을 사용하여 번호를 예측
def predict_kmeans_clustering(data, weeks_ago, n_clusters=5):
    numbers = data.iloc[:, 2:].values.flatten().reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(numbers)

    # 가장 빈번한 클러스터 선택
    cluster_counts = pd.Series(kmeans.labels_).value_counts()
    top_cluster = cluster_counts.idxmax()
    top_numbers = numbers[kmeans.labels_ == top_cluster]

    # 상위 6개의 번호 선택
    predicted_numbers = pd.Series(top_numbers.flatten()).value_counts().nlargest(6).index.tolist()
    return ensure_unique_numbers(predicted_numbers)

# 오토인코더를 사용하여 번호를 예측
def predict_autoencoder(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(numbers)

    # 오토인코더 정의
    input_dim = scaled_data.shape[1]
    autoencoder = Sequential([
        Input(shape=(input_dim,)),
        Dense(16, activation='relu'),
        Dense(input_dim, activation='sigmoid')
    ])
    autoencoder.compile(optimizer='adam', loss='mse')
    autoencoder.fit(scaled_data, scaled_data, epochs=50, batch_size=16, verbose=0)

    # 복원된 데이터로 패턴 분석
    decoded_data = autoencoder.predict(scaled_data)
    predicted_numbers = [int(round(num)) for num in decoded_data[-1] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# Markov Chain을 사용하여 번호를 예측
def predict_markov_chain(data, weeks_ago):
    numbers = data.iloc[:, 2:].values.flatten()
    transitions = pd.crosstab(numbers[:-1], numbers[1:])
    probabilities = transitions.div(transitions.sum(axis=1), axis=0)

    last_number = numbers[-1]
    if last_number in probabilities.index:
        next_numbers = probabilities.loc[last_number].nlargest(6).index.tolist()
    else:
        next_numbers = random.sample(range(1, 46), 6)  # 기본값으로 랜덤 샘플 제공

    return ensure_unique_numbers(next_numbers)

# 메인 함수
def main():
    try:
        file_path = "Loto_number.xlsx"  # 엑셀 파일 경로
        data = pd.read_excel(file_path)
    except Exception as e:
        print(f"데이터 로드 실패: {e}")
        return

    # 예측 함수 매핑
    prediction_functions = {
        "total_high_frequency        ": predict_high_frequency_numbers,
        "total_low_frequency         ": predict_low_frequency_numbers,
        "total_combined_frequency    ": predict_combined_frequency_numbers,
        "total_next_vector           ": predict_next_vector,

        "recent_52_high_frequency    ": predict_high_frequency_numbers,
        "recent_52_low_frequency     ": predict_low_frequency_numbers,
        "recent_52_combined_frequency": predict_combined_frequency_numbers,
        "recent_52_next_vector       ": predict_next_vector,

        "recent_26_high_frequency    ": predict_high_frequency_numbers,
        "recent_26_low_frequency     ": predict_low_frequency_numbers,
        "recent_26_combined_frequency": predict_combined_frequency_numbers,
        "recent_26_next_vector       ": predict_next_vector,

        "neural_network              ": predict_neural_network,
        "random_forest               ": predict_random_forest,
        "gradient_boosting           ": predict_gradient_boosting,
        "LSTM                        ": predict_lstm,
        "Bayesian                    ": predict_bayesian,
        "KMeans                      ": predict_kmeans_clustering,
        "AutoEncoder                 ": predict_autoencoder,
        "MarkovChain                 ": predict_markov_chain
    }

    # 모델 성능 평가
    total_rewards = evaluate_predictions(data, prediction_functions)

    print("\n### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###")
    for method, stats in total_rewards.items():
        total_reward = stats["total_reward"]
        win_count = stats["win_count"]
        print(f"{method}: 총 당첨 {total_reward}원({win_count}회)")
           
    print("\n### 다음 주 예상 번호 ###")
    all_predictions = []  # 모든 예측 결과를 저장할 리스트
    for method, func in prediction_functions.items():
        try:
            predicted = func(data, weeks_ago=1)
            predicted = ensure_unique_numbers(predicted)
            all_predictions.append(predicted)  # 앙상블에 포함할 결과 저장
            print(f"{method}: {predicted}")
        except Exception as e:
            print(f"{method}: 예측 실패 (오류: {e})")

    # 앙상블 예측 수행
    if all_predictions:
        ensemble_predictions = predict_ensemble_from_numpy([np.array(pred) for pred in all_predictions])
        print(f"\nEnsemble                    : {ensemble_predictions}")

if __name__ == "__main__":
    main()
# Out:
# ### (52주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 7, 13, 28, 36, 42]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# neural_network              : [4, 8, 23, 29, 35, 40] (당첨금: -1000원)
# random_forest               : [7, 14, 21, 26, 32, 41] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 12, 14, 22] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step
# LSTM                        : [6, 7, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [15, 18, 31, 33, 38, 45] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 12, 26, 33, 40] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 6, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 16, 18, 21, 32] (당첨금: -1000원)
#
# ### (51주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [13, 14, 22, 26, 37, 38]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# neural_network              : [4, 14, 24, 28, 33, 41] (당첨금: -1000원)
# random_forest               : [7, 15, 22, 25, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 13, 38, 39] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# LSTM                        : [7, 8, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [12, 14, 18, 34, 43, 45] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 15, 20, 22, 33, 44] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 5, 7, 43, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (50주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 12, 29, 31, 40, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 15, 22, 28, 35, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# neural_network              : [7, 12, 23, 26, 35, 42] (당첨금: -1000원)
# random_forest               : [6, 15, 21, 26, 34, 38] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 7, 8, 9, 31] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# LSTM                        : [8, 14, 19, 34, 38, 39] (당첨금: -1000원)
# Bayesian                    : [6, 18, 21, 27, 33, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 10, 14, 31, 36, 40] (당첨금: 4000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (49주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 7, 21, 30, 35, 38]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# neural_network              : [4, 12, 18, 22, 33, 42] (당첨금: -1000원)
# random_forest               : [9, 14, 21, 28, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [2, 5, 6, 7, 10, 11] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step
# LSTM                        : [6, 7, 34, 35, 40, 41] (당첨금: -1000원)
# Bayesian                    : [12, 14, 27, 33, 38, 45] (당첨금: -1000원)
# KMeans                      : [2, 3, 6, 7, 11, 12] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 15, 19, 22, 40, 45] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (48주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 16, 34, 37, 39, 40]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# neural_network              : [6, 10, 19, 22, 24, 38] (당첨금: -1000원)
# random_forest               : [7, 13, 19, 25, 33, 39] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 8, 10, 11, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step
# LSTM                        : [6, 12, 32, 33, 40, 41] (당첨금: -1000원)
# Bayesian                    : [12, 16, 18, 21, 23, 39] (당첨금: -1000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 29, 31, 40, 45] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (47주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 3, 4, 29, 42, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [11, 18, 24, 31, 37, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# neural_network              : [9, 15, 16, 29, 35, 38] (당첨금: -1000원)
# random_forest               : [9, 14, 20, 29, 35, 40] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 10, 12, 26, 38] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# LSTM                        : [6, 7, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [6, 18, 28, 34, 39, 43] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 13, 14, 21, 36, 37] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (46주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 14, 30, 31, 40, 41]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 9, 16, 22, 29, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# neural_network              : [6, 13, 14, 25, 33, 40] (당첨금: 4000원)
# random_forest               : [5, 11, 20, 23, 34, 38] (당첨금: -1000원)
# gradient_boosting           : [2, 7, 13, 25, 31, 32] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# LSTM                        : [6, 12, 19, 32, 38, 39] (당첨금: -1000원)
# Bayesian                    : [12, 16, 21, 30, 39, 43] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 6, 10, 31, 35] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (45주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 19, 26, 37, 39, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# neural_network              : [9, 12, 13, 26, 33, 44] (당첨금: -1000원)
# random_forest               : [8, 16, 23, 28, 33, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 13, 39] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step
# LSTM                        : [7, 13, 34, 35, 40, 41] (당첨금: -1000원)
# Bayesian                    : [12, 13, 33, 35, 38, 39] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 5, 19, 26, 31, 40] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (44주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 12, 13, 19, 33, 40]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [9, 16, 23, 29, 36, 42] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# neural_network              : [7, 11, 14, 23, 32, 38] (당첨금: -1000원)
# random_forest               : [7, 14, 23, 31, 35, 41] (당첨금: -1000원)
# gradient_boosting           : [6, 7, 8, 10, 32, 39] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# LSTM                        : [6, 7, 33, 34, 39, 40] (당첨금: -1000원)
# Bayesian                    : [6, 18, 19, 33, 36, 43] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 6, 23, 36, 43] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (43주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 7, 11, 20, 22, 41]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [9, 13, 14, 29, 35, 43] (당첨금: -1000원)
# random_forest               : [7, 16, 23, 31, 36, 41] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 7, 8, 11, 41] (당첨금: 4000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 289ms/step
# LSTM                        : [6, 12, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [1, 7, 12, 38, 39, 45] (당첨금: -1000원)
# KMeans                      : [3, 6, 7, 11, 12, 13] (당첨금: 4000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 21, 24, 33, 36, 38] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (42주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 13, 30, 33, 43, 45]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# neural_network              : [7, 14, 20, 26, 29, 39] (당첨금: -1000원)
# random_forest               : [5, 12, 19, 23, 29, 38] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 12, 24] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# LSTM                        : [6, 12, 33, 34, 40, 41] (당첨금: -1000원)
# Bayesian                    : [10, 16, 19, 21, 28, 39] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 15, 26, 36, 41, 44] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (41주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [16, 20, 26, 36, 42, 44]
# total_high_frequency        : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# total_next_vector           : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 18, 21, 33, 38, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [12, 19, 25, 32, 39, 45] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# neural_network              : [7, 13, 19, 23, 31, 39] (당첨금: -1000원)
# random_forest               : [9, 15, 21, 28, 35, 39] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 25, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# LSTM                        : [6, 7, 32, 33, 40, 41] (당첨금: -1000원)
# Bayesian                    : [2, 10, 12, 16, 18, 34] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 9, 10, 40, 43] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (40주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [11, 13, 20, 21, 32, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 32, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 44] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# neural_network              : [4, 14, 19, 26, 33, 39] (당첨금: -1000원)
# random_forest               : [6, 13, 22, 26, 35, 40] (당첨금: -1000원)
# gradient_boosting           : [2, 5, 6, 7, 21, 23] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# LSTM                        : [7, 12, 13, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [3, 12, 21, 36, 38, 45] (당첨금: -1000원)
# KMeans                      : [2, 3, 6, 7, 11, 12] (당첨금: -1000원)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 9, 14, 18, 24] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: 4000원)
#
# ### (39주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 16, 19, 32, 33, 38]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# total_next_vector           : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# recent_52_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 21, 25] (당첨금: -1000원)
# recent_26_next_vector       : [4, 11, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# neural_network              : [3, 7, 15, 27, 33, 40] (당첨금: -1000원)
# random_forest               : [7, 12, 20, 28, 36, 40] (당첨금: -1000원)
# gradient_boosting           : [3, 4, 5, 7, 15, 30] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step
# LSTM                        : [6, 12, 18, 32, 38, 39] (당첨금: -1000원)
# Bayesian                    : [14, 18, 19, 33, 38, 43] (당첨금: 4000원)
# KMeans                      : [17, 18, 19, 21, 24, 26] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 6, 9, 12, 19, 34] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (38주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [7, 12, 23, 32, 34, 36]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# total_next_vector           : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [8, 14, 21, 27, 34, 41] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# neural_network              : [7, 11, 21, 30, 32, 37] (당첨금: -1000원)
# random_forest               : [7, 14, 19, 26, 35, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 7, 8, 12, 20] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# LSTM                        : [6, 12, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [6, 7, 18, 21, 31, 43] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 14, 16, 18] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 6, 8, 22, 31] (당첨금: -1000원)
# MarkovChain                 : [3, 39, 40, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (37주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [15, 16, 17, 25, 30, 31]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# total_next_vector           : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [7, 13, 20, 26, 33, 40] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# neural_network              : [7, 9, 13, 24, 30, 38] (당첨금: -1000원)
# random_forest               : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 8, 43] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step
# LSTM                        : [8, 9, 14, 21, 33, 40] (당첨금: -1000원)
# Bayesian                    : [12, 19, 34, 38, 39, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 7, 7, 25, 31, 37] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (36주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 4, 9, 30, 33, 36]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 32, 39] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# neural_network              : [5, 12, 18, 23, 36, 38] (당첨금: -1000원)
# random_forest               : [8, 13, 21, 26, 33, 38] (당첨금: -1000원)
# gradient_boosting           : [3, 4, 6, 7, 8, 41] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# LSTM                        : [7, 14, 32, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [13, 15, 18, 21, 29, 45] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 7, 17, 20, 34, 44] (당첨금: -1000원)
# MarkovChain                 : [32, 33, 34, 35, 36, 39] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (35주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [11, 13, 14, 15, 16, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 24, 30, 37] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# neural_network              : [7, 9, 22, 25, 39, 42] (당첨금: -1000원)
# random_forest               : [6, 15, 19, 27, 36, 41] (당첨금: -1000원)
# gradient_boosting           : [1, 3, 5, 6, 7, 18] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# LSTM                        : [7, 8, 14, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [3, 6, 21, 33, 38, 45] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 14, 15, 28, 33, 41] (당첨금: -1000원)
# MarkovChain                 : [1, 37, 38, 39, 40, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 21, 32, 33] (당첨금: -1000원)
#
# ### (34주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 9, 12, 13, 20, 45]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# total_next_vector           : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# recent_52_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: 4000원)
# recent_26_next_vector       : [5, 12, 18, 25, 31, 38] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# neural_network              : [8, 14, 19, 27, 32, 41] (당첨금: -1000원)
# random_forest               : [7, 14, 20, 25, 34, 41] (당첨금: -1000원)
# gradient_boosting           : [4, 5, 6, 7, 8, 34] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step
# LSTM                        : [7, 13, 21, 22, 34, 40] (당첨금: -1000원)
# Bayesian                    : [7, 12, 24, 33, 42, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 13, 15, 31, 37, 43] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 21, 32, 33] (당첨금: -1000원)
#
# ### (33주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [2, 19, 26, 31, 38, 41]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [4, 10, 17, 23, 30, 36] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# neural_network              : [5, 14, 15, 26, 32, 39] (당첨금: -1000원)
# random_forest               : [5, 15, 20, 26, 32, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 7, 9, 18, 27] (당첨금: -1000원)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# LSTM                        : [7, 15, 21, 34, 40, 41] (당첨금: -1000원)
# Bayesian                    : [6, 7, 12, 13, 21, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 14, 16, 18] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 9, 13, 14, 40, 45] (당첨금: -1000원)
# MarkovChain                 : [1, 2, 3, 4, 5, 6] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 32] (당첨금: -1000원)
#
# ### (32주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 24, 31, 32, 38, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 18, 25, 31, 38, 44] (당첨금: 4000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# neural_network              : [6, 12, 21, 26, 29, 41] (당첨금: -1000원)
# random_forest               : [7, 14, 20, 27, 32, 38] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 8, 40, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# LSTM                        : [7, 8, 34, 35, 40, 41] (당첨금: -1000원)
# Bayesian                    : [12, 13, 21, 33, 38, 45] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 4, 25, 31, 39, 42] (당첨금: -1000원)
# MarkovChain                 : [2, 4, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (31주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 6, 21, 30, 34, 35]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 17, 23, 30, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# neural_network              : [8, 16, 31, 37, 39, 42] (당첨금: -1000원)
# random_forest               : [7, 11, 18, 27, 35, 38] (당첨금: -1000원)
# gradient_boosting           : [3, 4, 6, 7, 8, 9] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# LSTM                        : [5, 11, 12, 18, 32, 39] (당첨금: -1000원)
# Bayesian                    : [11, 18, 33, 38, 43, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 7, 34, 36, 40, 44] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (30주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [13, 19, 21, 24, 34, 35]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [3, 10, 16, 23, 29, 36] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# neural_network              : [6, 16, 22, 29, 35, 42] (당첨금: -1000원)
# random_forest               : [6, 13, 19, 27, 34, 41] (당첨금: 4000원)
# gradient_boosting           : [4, 6, 8, 9, 16, 19] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# LSTM                        : [7, 13, 32, 33, 38, 39] (당첨금: -1000원)
# Bayesian                    : [2, 6, 12, 39, 43, 45] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# AutoEncoder                 : [1, 4, 11, 13, 39, 43] (당첨금: -1000원)
# MarkovChain                 : [36, 37, 38, 39, 42, 43] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (29주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [3, 8, 17, 30, 33, 34]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# total_next_vector           : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# recent_52_next_vector       : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 21, 25] (당첨금: -1000원)
# recent_26_next_vector       : [8, 15, 22, 28, 35, 41] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# neural_network              : [6, 13, 14, 29, 35, 37] (당첨금: -1000원)
# random_forest               : [7, 12, 21, 28, 36, 41] (당첨금: -1000원)
# gradient_boosting           : [2, 5, 6, 8, 9, 14] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# LSTM                        : [6, 7, 12, 32, 38, 39] (당첨금: -1000원)
# Bayesian                    : [2, 6, 19, 21, 33, 41] (당첨금: -1000원)
# KMeans                      : [12, 13, 16, 18, 19, 21] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 16, 20, 34, 42] (당첨금: -1000원)
# MarkovChain                 : [36, 37, 38, 39, 42, 43] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (28주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 14, 25, 33, 40, 44]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 40] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [5, 11, 18, 24, 31, 37] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# neural_network              : [5, 8, 19, 22, 30, 37] (당첨금: -1000원)
# random_forest               : [7, 11, 20, 26, 35, 39] (당첨금: -1000원)
# gradient_boosting           : [3, 5, 6, 7, 9, 40] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# LSTM                        : [6, 12, 13, 21, 33, 41] (당첨금: -1000원)
# Bayesian                    : [16, 18, 21, 33, 38, 43] (당첨금: -1000원)
# KMeans                      : [18, 19, 21, 24, 26, 27] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 5, 11, 19, 40] (당첨금: -1000원)
# MarkovChain                 : [35, 36, 37, 38, 39, 42] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (27주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [4, 5, 9, 11, 37, 40]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# total_combined_frequency    : [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# total_next_vector           : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# recent_52_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_52_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 9, 20, 25, 32, 37] (당첨금: 4000원)
# recent_26_combined_frequency: [5, 9, 12, 18, 20, 33] (당첨금: -1000원)
# recent_26_next_vector       : [11, 17, 24, 30, 37, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# neural_network              : [6, 11, 15, 24, 33, 40] (당첨금: -1000원)
# random_forest               : [5, 10, 20, 23, 32, 38] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 9, 10, 11, 41] (당첨금: 4000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# LSTM                        : [7, 13, 21, 35, 40, 41] (당첨금: -1000원)
# Bayesian                    : [13, 19, 21, 30, 34, 38] (당첨금: -1000원)
# KMeans                      : [30, 31, 33, 34, 35, 36] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 10, 12, 21, 39, 43] (당첨금: -1000원)
# MarkovChain                 : [2, 3, 4, 5, 7, 10] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (26주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [10, 15, 24, 30, 31, 37]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [1, 8, 14, 21, 27, 34] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# neural_network              : [7, 12, 17, 22, 28, 39] (당첨금: -1000원)
# random_forest               : [7, 13, 20, 27, 34, 40] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 7, 8, 12, 39] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# LSTM                        : [6, 13, 20, 33, 39, 40] (당첨금: -1000원)
# Bayesian                    : [6, 7, 12, 33, 34, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 5, 25, 27, 38, 45] (당첨금: -1000원)
# MarkovChain                 : [2, 41, 42, 43, 44, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (25주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 5, 8, 16, 28, 33]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [10, 16, 23, 29, 36, 43] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# neural_network              : [5, 6, 16, 20, 28, 35] (당첨금: 4000원)
# random_forest               : [6, 12, 18, 23, 32, 38] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 7, 8, 11, 37] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# LSTM                        : [6, 7, 34, 35, 40, 41] (당첨금: -1000원)
# Bayesian                    : [3, 13, 16, 30, 33, 44] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AutoEncoder                 : [1, 8, 15, 26, 34, 38] (당첨금: -1000원)
# MarkovChain                 : [38, 39, 40, 41, 42, 45] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (24주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [5, 10, 11, 17, 28, 34]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [7, 13, 20, 26, 32, 33] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [7, 13, 14, 20, 26, 33] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [7, 13, 20, 26, 32, 33] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# neural_network              : [6, 11, 19, 25, 33, 39] (당첨금: -1000원)
# random_forest               : [5, 12, 18, 25, 32, 41] (당첨금: -1000원)
# gradient_boosting           : [5, 7, 8, 9, 11, 21] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# LSTM                        : [7, 13, 20, 33, 34, 40] (당첨금: -1000원)
# Bayesian                    : [1, 16, 21, 28, 38, 45] (당첨금: -1000원)
# KMeans                      : [11, 12, 13, 16, 18, 19] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 3, 25, 28, 35, 43] (당첨금: -1000원)
# MarkovChain                 : [34, 35, 36, 37, 38, 40] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (23주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [15, 19, 21, 25, 27, 28]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# total_next_vector           : [6, 12, 19, 25, 32, 38] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_52_next_vector       : [6, 12, 19, 25, 32, 38] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 12, 18, 20, 25, 33] (당첨금: -1000원)
# recent_26_next_vector       : [6, 12, 19, 25, 32, 38] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# neural_network              : [5, 12, 13, 28, 30, 38] (당첨금: -1000원)
# random_forest               : [7, 11, 18, 25, 34, 39] (당첨금: -1000원)
# gradient_boosting           : [5, 6, 7, 8, 9, 12] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# LSTM                        : [6, 7, 13, 20, 33, 40] (당첨금: -1000원)
# Bayesian                    : [3, 11, 12, 18, 41, 43] (당첨금: -1000원)
# KMeans                      : [36, 38, 39, 43, 44, 45] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 2, 12, 17, 27, 38] (당첨금: -1000원)
# MarkovChain                 : [35, 36, 37, 38, 39, 42] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (22주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [1, 2, 6, 14, 27, 38]
# total_high_frequency        : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 18, 20, 21, 33] (당첨금: -1000원)
# total_next_vector           : [9, 15, 22, 28, 35, 41] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 18, 20, 21, 33] (당첨금: -1000원)
# recent_52_next_vector       : [9, 15, 22, 28, 35, 41] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 45] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 18, 20, 21, 33] (당첨금: -1000원)
# recent_26_next_vector       : [9, 15, 22, 28, 35, 41] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# neural_network              : [6, 12, 22, 30, 35, 40] (당첨금: -1000원)
# random_forest               : [8, 15, 22, 26, 33, 41] (당첨금: -1000원)
# gradient_boosting           : [4, 6, 7, 8, 10, 13] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# LSTM                        : [7, 13, 34, 35, 40, 41] (당첨금: -1000원)
# Bayesian                    : [6, 18, 19, 24, 33, 38] (당첨금: -1000원)
# KMeans                      : [28, 30, 31, 33, 34, 36] (당첨금: -1000원)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# AutoEncoder                 : [1, 6, 15, 32, 33, 43] (당첨금: -1000원)
# MarkovChain                 : [29, 30, 31, 34, 36, 38] (당첨금: -1000원)
# Ensemble                    : [5, 12, 18, 20, 21, 33] (당첨금: -1000원)
#
# ### (21주전)예측되는 번호와 당첨 금액 ###
# => 실제 당첨 번호           : [6, 7, 19, 28, 34, 41]
# total_high_frequency        : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# total_low_frequency         : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# total_combined_frequency    : [5, 9, 18, 20, 21, 33] (당첨금: -1000원)
# total_next_vector           : [1, 7, 14, 20, 27, 33] (당첨금: -1000원)
# recent_52_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_52_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_52_combined_frequency: [5, 9, 18, 20, 21, 33] (당첨금: -1000원)
# recent_52_next_vector       : [1, 7, 14, 20, 27, 33] (당첨금: -1000원)
# recent_26_high_frequency    : [12, 16, 18, 21, 33, 38] (당첨금: -1000원)
# recent_26_low_frequency     : [5, 8, 9, 20, 25, 32] (당첨금: -1000원)
# recent_26_combined_frequency: [5, 9, 18, 20, 21, 33] (당첨금: -1000원)
# recent_26_next_vector       : [1, 7, 14, 20, 27, 33] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# neural_network              : [3, 9, 16, 28, 34, 38] (당첨금: -1000원)
# random_forest               : [6, 13, 20, 28, 37, 41] (당첨금: 4000원)
# gradient_boosting           : [5, 6, 8, 9, 11, 12] (당첨금: -1000원)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# LSTM                        : [6, 7, 33, 34, 40, 41] (당첨금: 49000원)

# %%
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
import numpy as np
from skopt import gp_minimize
from skopt.space import Integer

# 번호의 중복 제거 및 부족 시 채워주는 함수
def ensure_unique_numbers(numbers):
    numbers = list(set(numbers))  # 중복 제거
    while len(numbers) < 6:
        numbers.append(random.randint(1, 45))  # 부족한 번호를 무작위로 추가
    return sorted(numbers[:6])

# 실제 번호와 예측 번호를 비교하여 보상을 계산하는 함수
def calculate_rewards(actual, predicted):
    match_count = len(set(actual) & set(predicted))  # 일치하는 번호 개수 계산
    rewards = {6: 10_000_000_000, 5: 1_499_000, 4: 49_000, 3: 4_000}
    return rewards.get(match_count, -1_000)  # 일치하지 않으면 -1,000 반환

# 앙상블 예측 함수
def predict_ensemble_from_numpy(predictions_list):
    """
    각 모델의 예측값을 numpy array로 받아 앙상블 예측 수행.
    """
    flat_predictions = np.concatenate(predictions_list).flatten()
    flat_predictions = flat_predictions[(flat_predictions >= 1) & (flat_predictions <= 45)]  # 유효 번호 필터링
    frequency_counts = pd.Series(flat_predictions).value_counts()

    if frequency_counts.empty:
        print("빈도 계산 결과가 없습니다. 빈 결과를 반환합니다.")
        return []

    return ensure_unique_numbers(frequency_counts.nlargest(6).index.tolist())

# 예측 모델의 성능을 평가하는 함수
def evaluate_predictions(data, prediction_functions, weeks_to_evaluate=52):
    total_rewards = {method: {"total_reward": 0, "win_count": 0} for method in prediction_functions.keys()}
    total_rewards["Ensemble"] = {"total_reward": 0, "win_count": 0}  # 앙상블 결과 추가
    prediction_storage = {method: [] for method in prediction_functions.keys()}

    for weeks_ago in range(weeks_to_evaluate, 0, -1):
        train_data = data[:-weeks_ago]
        test_data = data.iloc[-weeks_ago].values[2:]

        print(f"\n### ({weeks_ago}주전)예측되는 번호와 당첨 금액 ###")
        print(f"=> 실제 당첨 번호           : {sorted(test_data)}")

        for method, func in prediction_functions.items():
            predicted = func(train_data, weeks_ago)
            predicted = ensure_unique_numbers(predicted)

            if not predicted:
                print(f"{method}의 예측 결과가 비어 있습니다.")
                continue

            prediction_storage[method].append(predicted)  # 숫자 리스트 저장
            reward = calculate_rewards(test_data, predicted)
            total_rewards[method]["total_reward"] += reward
            if reward > 0:
                total_rewards[method]["win_count"] += 1

            print(f"{method}: {sorted(predicted)} (당첨금: {reward}원)")

        # 앙상블 예측 수행
        ensemble_predictions = predict_ensemble_from_numpy(
            [np.array(prediction_storage[method]) for method in prediction_storage]
        )
        ensemble_reward = calculate_rewards(test_data, ensemble_predictions)
        total_rewards["Ensemble"]["total_reward"] += ensemble_reward
        if ensemble_reward > 0:
            total_rewards["Ensemble"]["win_count"] += 1

        print(f"Ensemble                    : {ensemble_predictions} (당첨금: {ensemble_reward}원)")

    return total_rewards

# 높은 빈도의 숫자를 기반으로 예측
def predict_high_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nlargest(6).index.tolist()  # 상위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 낮은 빈도의 숫자를 기반으로 예측
def predict_low_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nsmallest(6).index.tolist()  # 하위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 높은 빈도 3개 + 낮은 빈도 3개 조합으로 예측
def predict_combined_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    most_frequent = frequency_counts.nlargest(3).index.tolist()  # 상위 3개 숫자
    least_frequent = frequency_counts.nsmallest(3).index.tolist()  # 하위 3개 숫자
    return ensure_unique_numbers(most_frequent + least_frequent)

# PCA를 사용하여 다음 벡터를 예측
def predict_next_vector(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(numbers)  # 데이터 스케일링

    pca = PCA(n_components=1)
    principal_component = pca.fit_transform(scaled_data)  # PCA 변환

    next_vector = principal_component[-1] + (principal_component[-1] - principal_component[-2])  # 다음 벡터 예측
    inverse_scaled_vector = scaler.inverse_transform(scaled_data.mean(axis=0).reshape(1, -1)) + next_vector

    predicted_numbers = [int(round(num)) for num in inverse_scaled_vector[0] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# 신경망을 사용하여 번호를 예측
def predict_neural_network(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(6, activation='sigmoid')  # Using sigmoid to restrict range
    ])

    model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mae'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])

    # Add random noise (jitter) to each prediction
    jittered_predictions = predictions + np.random.uniform(-0.05, 0.05, size=predictions.shape)
    jittered_predictions = np.clip(jittered_predictions, 0, 1)  # Ensure valid range for sigmoid outputs

    # Inverse transform to original scale
    inverse_transformed = scaler_y.inverse_transform(jittered_predictions)

    # Convert to integers and ensure range
    rounded_numbers = [int(round(num)) for num in inverse_transformed.flatten() if 1 <= round(num) <= 45]
    return ensure_unique_numbers(rounded_numbers[:6])

# 랜덤 포레스트를 사용하여 번호를 예측
def predict_random_forest(data, weeks_ago):
    from sklearn.ensemble import RandomForestRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# Gradient Boosting을 사용하여 번호를 예측
def predict_gradient_boosting(data, weeks_ago):
    from sklearn.ensemble import GradientBoostingRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    y_train = y_train.iloc[:, 0].values
    y_test = y_test.iloc[:, 0].values

    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# LSTM을 사용하여 번호를 예측
def predict_lstm(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(numbers)

    X, y = [], []
    for i in range(len(scaled_data) - 10):
        X.append(scaled_data[i:i + 10])
        y.append(scaled_data[i + 10])

    X, y = np.array(X), np.array(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(128, return_sequences=True),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(6, activation='linear')
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])
    predicted_numbers = scaler.inverse_transform(predictions).flatten()
    return ensure_unique_numbers([int(round(num)) for num in predicted_numbers if 1 <= round(num) <= 45])

# Bayesian Optimization을 사용하여 번호를 예측
def predict_bayesian(data, weeks_ago):
    numbers = data.iloc[:, 2:].values

    def objective_function(x):
        selected_numbers = x
        count = sum(num in selected_numbers for num in numbers.flatten())
        return -count

    search_space = [Integer(1, 45) for _ in range(6)]
    result = gp_minimize(objective_function, search_space, n_calls=100)
    return ensure_unique_numbers(result.x)

# K-평균 클러스터링을 사용하여 번호를 예측
def predict_kmeans_clustering(data, weeks_ago, n_clusters=5):
    numbers = data.iloc[:, 2:].values.flatten().reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(numbers)

    # 가장 빈번한 클러스터 선택
    cluster_counts = pd.Series(kmeans.labels_).value_counts()
    top_cluster = cluster_counts.idxmax()
    top_numbers = numbers[kmeans.labels_ == top_cluster]

    # 상위 6개의 번호 선택
    predicted_numbers = pd.Series(top_numbers.flatten()).value_counts().nlargest(6).index.tolist()
    return ensure_unique_numbers(predicted_numbers)

# 오토인코더를 사용하여 번호를 예측
def predict_autoencoder(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(numbers)

    # 오토인코더 정의
    input_dim = scaled_data.shape[1]
    autoencoder = Sequential([
        Input(shape=(input_dim,)),
        Dense(16, activation='relu'),
        Dense(input_dim, activation='sigmoid')
    ])
    autoencoder.compile(optimizer='adam', loss='mse')
    autoencoder.fit(scaled_data, scaled_data, epochs=50, batch_size=16, verbose=0)

    # 복원된 데이터로 패턴 분석
    decoded_data = autoencoder.predict(scaled_data)
    predicted_numbers = [int(round(num)) for num in decoded_data[-1] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# Markov Chain을 사용하여 번호를 예측
def predict_markov_chain(data, weeks_ago):
    numbers = data.iloc[:, 2:].values.flatten()
    transitions = pd.crosstab(numbers[:-1], numbers[1:])
    probabilities = transitions.div(transitions.sum(axis=1), axis=0)

    last_number = numbers[-1]
    if last_number in probabilities.index:
        next_numbers = probabilities.loc[last_number].nlargest(6).index.tolist()
    else:
        next_numbers = random.sample(range(1, 46), 6)  # 기본값으로 랜덤 샘플 제공

    return ensure_unique_numbers(next_numbers)

# 메인 함수
def main():
    try:
        file_path = "Loto_number.xlsx"  # 엑셀 파일 경로
        data = pd.read_excel(file_path)
    except Exception as e:
        print(f"데이터 로드 실패: {e}")
        return

    # 예측 함수 매핑
    prediction_functions = {
        "total_high_frequency        ": predict_high_frequency_numbers,
        "total_low_frequency         ": predict_low_frequency_numbers,
        "total_combined_frequency    ": predict_combined_frequency_numbers,
        "total_next_vector           ": predict_next_vector,

        "recent_52_high_frequency    ": predict_high_frequency_numbers,
        "recent_52_low_frequency     ": predict_low_frequency_numbers,
        "recent_52_combined_frequency": predict_combined_frequency_numbers,
        "recent_52_next_vector       ": predict_next_vector,

        "recent_26_high_frequency    ": predict_high_frequency_numbers,
        "recent_26_low_frequency     ": predict_low_frequency_numbers,
        "recent_26_combined_frequency": predict_combined_frequency_numbers,
        "recent_26_next_vector       ": predict_next_vector,

        "neural_network              ": predict_neural_network,
        "random_forest               ": predict_random_forest,
        "gradient_boosting           ": predict_gradient_boosting,
        "LSTM                        ": predict_lstm,
        "Bayesian                    ": predict_bayesian,
        "KMeans                      ": predict_kmeans_clustering,
        "AutoEncoder                 ": predict_autoencoder,
        "MarkovChain                 ": predict_markov_chain
    }

    # 모델 성능 평가
    total_rewards = evaluate_predictions(data, prediction_functions)

    print("\n### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###")
    for method, stats in total_rewards.items():
        total_reward = stats["total_reward"]
        win_count = stats["win_count"]
        print(f"{method}: 총 당첨 {total_reward}원({win_count}회)")
           
    print("\n### 다음 주 예상 번호 ###")
    all_predictions = []  # 모든 예측 결과를 저장할 리스트
    for method, func in prediction_functions.items():
        try:
            predicted = func(data, weeks_ago=1)
            predicted = ensure_unique_numbers(predicted)
            all_predictions.append(predicted)  # 앙상블에 포함할 결과 저장
            print(f"{method}: {predicted}")
        except Exception as e:
            print(f"{method}: 예측 실패 (오류: {e})")

    # 앙상블 예측 수행
    if all_predictions:
        ensemble_predictions = predict_ensemble_from_numpy([np.array(pred) for pred in all_predictions])
        print(f"\nEnsemble                    : {ensemble_predictions}")

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
import numpy as np
from skopt import gp_minimize
from skopt.space import Integer

# 번호의 중복 제거 및 부족 시 채워주는 함수
def ensure_unique_numbers(numbers):
    numbers = list(set(numbers))  # 중복 제거
    while len(numbers) < 6:
        numbers.append(random.randint(1, 45))  # 부족한 번호를 무작위로 추가
    return sorted(numbers[:6])

# 실제 번호와 예측 번호를 비교하여 보상을 계산하는 함수
def calculate_rewards(actual, predicted):
    match_count = len(set(actual) & set(predicted))  # 일치하는 번호 개수 계산
    rewards = {6: 10_000_000_000, 5: 1_499_000, 4: 49_000, 3: 4_000}
    return rewards.get(match_count, -1_000)  # 일치하지 않으면 -1,000 반환

# 앙상블 예측 함수
def predict_ensemble_from_numpy(predictions_list):
    """
    각 모델의 예측값을 numpy array로 받아 앙상블 예측 수행.
    """
    flat_predictions = np.concatenate(predictions_list).flatten()
    flat_predictions = flat_predictions[(flat_predictions >= 1) & (flat_predictions <= 45)]  # 유효 번호 필터링
    frequency_counts = pd.Series(flat_predictions).value_counts()

    if frequency_counts.empty:
        print("빈도 계산 결과가 없습니다. 빈 결과를 반환합니다.")
        return []

    return ensure_unique_numbers(frequency_counts.nlargest(6).index.tolist())

# 예측 모델의 성능을 평가하는 함수
def evaluate_predictions(data, prediction_functions, weeks_to_evaluate=52):
    total_rewards = {method: {"total_reward": 0, "win_count": 0} for method in prediction_functions.keys()}
    total_rewards["Ensemble"] = {"total_reward": 0, "win_count": 0}  # 앙상블 결과 추가
    prediction_storage = {method: [] for method in prediction_functions.keys()}

    for weeks_ago in range(weeks_to_evaluate, 0, -1):
        train_data = data[:-weeks_ago]
        test_data = data.iloc[-weeks_ago].values[2:]

        print(f"\n### ({weeks_ago}주전)예측되는 번호와 당첨 금액 ###")
        print(f"=> 실제 당첨 번호           : {sorted(test_data)}")

        for method, func in prediction_functions.items():
            predicted = func(train_data, weeks_ago)
            predicted = ensure_unique_numbers(predicted)

            if not predicted:
                print(f"{method}의 예측 결과가 비어 있습니다.")
                continue

            prediction_storage[method].append(predicted)  # 숫자 리스트 저장
            reward = calculate_rewards(test_data, predicted)
            total_rewards[method]["total_reward"] += reward
            if reward > 0:
                total_rewards[method]["win_count"] += 1

            print(f"{method}: {sorted(predicted)} (당첨금: {reward}원)")

        # 앙상블 예측 수행
        ensemble_predictions = predict_ensemble_from_numpy(
            [np.array(prediction_storage[method]) for method in prediction_storage]
        )
        ensemble_reward = calculate_rewards(test_data, ensemble_predictions)
        total_rewards["Ensemble"]["total_reward"] += ensemble_reward
        if ensemble_reward > 0:
            total_rewards["Ensemble"]["win_count"] += 1

        print(f"Ensemble                    : {ensemble_predictions} (당첨금: {ensemble_reward}원)")

    return total_rewards

# 높은 빈도의 숫자를 기반으로 예측
def predict_high_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nlargest(6).index.tolist()  # 상위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 낮은 빈도의 숫자를 기반으로 예측
def predict_low_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nsmallest(6).index.tolist()  # 하위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 높은 빈도 3개 + 낮은 빈도 3개 조합으로 예측
def predict_combined_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    most_frequent = frequency_counts.nlargest(3).index.tolist()  # 상위 3개 숫자
    least_frequent = frequency_counts.nsmallest(3).index.tolist()  # 하위 3개 숫자
    return ensure_unique_numbers(most_frequent + least_frequent)

# PCA를 사용하여 다음 벡터를 예측
def predict_next_vector(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(numbers)  # 데이터 스케일링

    pca = PCA(n_components=1)
    principal_component = pca.fit_transform(scaled_data)  # PCA 변환

    next_vector = principal_component[-1] + (principal_component[-1] - principal_component[-2])  # 다음 벡터 예측
    inverse_scaled_vector = scaler.inverse_transform(scaled_data.mean(axis=0).reshape(1, -1)) + next_vector

    predicted_numbers = [int(round(num)) for num in inverse_scaled_vector[0] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# 신경망을 사용하여 번호를 예측
def predict_neural_network(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(6, activation='sigmoid')  # Using sigmoid to restrict range
    ])

    model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mae'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])

    # Add random noise (jitter) to each prediction
    jittered_predictions = predictions + np.random.uniform(-0.05, 0.05, size=predictions.shape)
    jittered_predictions = np.clip(jittered_predictions, 0, 1)  # Ensure valid range for sigmoid outputs

    # Inverse transform to original scale
    inverse_transformed = scaler_y.inverse_transform(jittered_predictions)

    # Convert to integers and ensure range
    rounded_numbers = [int(round(num)) for num in inverse_transformed.flatten() if 1 <= round(num) <= 45]
    return ensure_unique_numbers(rounded_numbers[:6])

# 랜덤 포레스트를 사용하여 번호를 예측
def predict_random_forest(data, weeks_ago):
    from sklearn.ensemble import RandomForestRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# Gradient Boosting을 사용하여 번호를 예측
def predict_gradient_boosting(data, weeks_ago):
    from sklearn.ensemble import GradientBoostingRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    y_train = y_train.iloc[:, 0].values
    y_test = y_test.iloc[:, 0].values

    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# LSTM을 사용하여 번호를 예측
def predict_lstm(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(numbers)

    X, y = [], []
    for i in range(len(scaled_data) - 10):
        X.append(scaled_data[i:i + 10])
        y.append(scaled_data[i + 10])

    X, y = np.array(X), np.array(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(128, return_sequences=True),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(6, activation='linear')
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])
    predicted_numbers = scaler.inverse_transform(predictions).flatten()
    return ensure_unique_numbers([int(round(num)) for num in predicted_numbers if 1 <= round(num) <= 45])

# Bayesian Optimization을 사용하여 번호를 예측
def predict_bayesian(data, weeks_ago):
    numbers = data.iloc[:, 2:].values

    def objective_function(x):
        selected_numbers = x
        count = sum(num in selected_numbers for num in numbers.flatten())
        return -count

    search_space = [Integer(1, 45) for _ in range(6)]
    result = gp_minimize(objective_function, search_space, n_calls=100)
    return ensure_unique_numbers(result.x)

# K-평균 클러스터링을 사용하여 번호를 예측
def predict_kmeans_clustering(data, weeks_ago, n_clusters=5):
    numbers = data.iloc[:, 2:].values.flatten().reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(numbers)

    # 가장 빈번한 클러스터 선택
    cluster_counts = pd.Series(kmeans.labels_).value_counts()
    top_cluster = cluster_counts.idxmax()
    top_numbers = numbers[kmeans.labels_ == top_cluster]

    # 상위 6개의 번호 선택
    predicted_numbers = pd.Series(top_numbers.flatten()).value_counts().nlargest(6).index.tolist()
    return ensure_unique_numbers(predicted_numbers)

# 오토인코더를 사용하여 번호를 예측
def predict_autoencoder(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(numbers)

    # 오토인코더 정의
    input_dim = scaled_data.shape[1]
    autoencoder = Sequential([
        Input(shape=(input_dim,)),
        Dense(16, activation='relu'),
        Dense(input_dim, activation='sigmoid')
    ])
    autoencoder.compile(optimizer='adam', loss='mse')
    autoencoder.fit(scaled_data, scaled_data, epochs=50, batch_size=16, verbose=0)

    # 복원된 데이터로 패턴 분석
    decoded_data = autoencoder.predict(scaled_data)
    predicted_numbers = [int(round(num)) for num in decoded_data[-1] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# Markov Chain을 사용하여 번호를 예측
def predict_markov_chain(data, weeks_ago):
    numbers = data.iloc[:, 2:].values.flatten()
    transitions = pd.crosstab(numbers[:-1], numbers[1:])
    probabilities = transitions.div(transitions.sum(axis=1), axis=0)

    last_number = numbers[-1]
    if last_number in probabilities.index:
        next_numbers = probabilities.loc[last_number].nlargest(6).index.tolist()
    else:
        next_numbers = random.sample(range(1, 46), 6)  # 기본값으로 랜덤 샘플 제공

    return ensure_unique_numbers(next_numbers)

# 메인 함수
def main():
    try:
        file_path = "Loto_number.xlsx"  # 엑셀 파일 경로
        data = pd.read_excel(file_path)
    except Exception as e:
        print(f"데이터 로드 실패: {e}")
        return

    # 예측 함수 매핑
    prediction_functions = {
        "total_high_frequency        ": predict_high_frequency_numbers,
        "total_low_frequency         ": predict_low_frequency_numbers,
        "total_combined_frequency    ": predict_combined_frequency_numbers,
        "total_next_vector           ": predict_next_vector,

        "recent_52_high_frequency    ": predict_high_frequency_numbers,
        "recent_52_low_frequency     ": predict_low_frequency_numbers,
        "recent_52_combined_frequency": predict_combined_frequency_numbers,
        "recent_52_next_vector       ": predict_next_vector,

        "recent_26_high_frequency    ": predict_high_frequency_numbers,
        "recent_26_low_frequency     ": predict_low_frequency_numbers,
        "recent_26_combined_frequency": predict_combined_frequency_numbers,
        "recent_26_next_vector       ": predict_next_vector,

        "neural_network              ": predict_neural_network,
        "random_forest               ": predict_random_forest,
        "gradient_boosting           ": predict_gradient_boosting,
        "LSTM                        ": predict_lstm,
        "Bayesian                    ": predict_bayesian,
        "KMeans                      ": predict_kmeans_clustering,
        "AutoEncoder                 ": predict_autoencoder,
        "MarkovChain                 ": predict_markov_chain
    }

    # 모델 성능 평가
    total_rewards = evaluate_predictions(data, prediction_functions)

    print("\n### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###")
    for method, stats in total_rewards.items():
        total_reward = stats["total_reward"]
        win_count = stats["win_count"]
        print(f"{method}: 총 당첨 {total_reward}원({win_count}회)")
           
    print("\n### 다음 주 예상 번호 ###")
    all_predictions = []  # 모든 예측 결과를 저장할 리스트
    for method, func in prediction_functions.items():
        try:
            predicted = func(data, weeks_ago=1)
            predicted = ensure_unique_numbers(predicted)
            all_predictions.append(predicted)  # 앙상블에 포함할 결과 저장
            print(f"{method}: {predicted}")
        except Exception as e:
            print(f"{method}: 예측 실패 (오류: {e})")

    # 앙상블 예측 수행
    if all_predictions:
        ensemble_predictions = predict_ensemble_from_numpy([np.array(pred) for pred in all_predictions])
        print(f"\nEnsemble                    : {ensemble_predictions}")

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
import numpy as np
from skopt import gp_minimize
from skopt.space import Integer

# 번호의 중복 제거 및 부족 시 채워주는 함수
def ensure_unique_numbers(numbers):
    numbers = list(set(numbers))  # 중복 제거
    while len(numbers) < 6:
        numbers.append(random.randint(1, 45))  # 부족한 번호를 무작위로 추가
    return sorted(numbers[:6])

# 실제 번호와 예측 번호를 비교하여 보상을 계산하는 함수
def calculate_rewards(actual, predicted):
    match_count = len(set(actual) & set(predicted))  # 일치하는 번호 개수 계산
    rewards = {6: 10_000_000_000, 5: 1_499_000, 4: 49_000, 3: 4_000}
    return rewards.get(match_count, -1_000)  # 일치하지 않으면 -1,000 반환

# 앙상블 예측 함수
def predict_ensemble_from_numpy(predictions_list):
    """
    각 모델의 예측값을 numpy array로 받아 앙상블 예측 수행.
    """
    flat_predictions = np.concatenate(predictions_list).flatten()
    flat_predictions = flat_predictions[(flat_predictions >= 1) & (flat_predictions <= 45)]  # 유효 번호 필터링
    frequency_counts = pd.Series(flat_predictions).value_counts()

    if frequency_counts.empty:
        print("빈도 계산 결과가 없습니다. 빈 결과를 반환합니다.")
        return []

    return ensure_unique_numbers(frequency_counts.nlargest(6).index.tolist())

# 예측 모델의 성능을 평가하는 함수
def evaluate_predictions(data, prediction_functions, weeks_to_evaluate=52):
    total_rewards = {method: {"total_reward": 0, "win_count": 0} for method in prediction_functions.keys()}
    total_rewards["Ensemble"] = {"total_reward": 0, "win_count": 0}  # 앙상블 결과 추가
    prediction_storage = {method: [] for method in prediction_functions.keys()}

    for weeks_ago in range(weeks_to_evaluate, 0, -1):
        train_data = data[:-weeks_ago]
        test_data = data.iloc[-weeks_ago].values[2:]

        print(f"\n### ({weeks_ago}주전)예측되는 번호와 당첨 금액 ###")
        print(f"=> 실제 당첨 번호           : {sorted(test_data)}")

        for method, func in prediction_functions.items():
            predicted = func(train_data, weeks_ago)
            predicted = ensure_unique_numbers(predicted)

            if not predicted:
                print(f"{method}의 예측 결과가 비어 있습니다.")
                continue

            prediction_storage[method].append(predicted)  # 숫자 리스트 저장
            reward = calculate_rewards(test_data, predicted)
            total_rewards[method]["total_reward"] += reward
            if reward > 0:
                total_rewards[method]["win_count"] += 1

            print(f"{method}: {sorted(predicted)} (당첨금: {reward}원)")

        # 앙상블 예측 수행
        ensemble_predictions = predict_ensemble_from_numpy(
            [np.array(prediction_storage[method]) for method in prediction_storage]
        )
        ensemble_reward = calculate_rewards(test_data, ensemble_predictions)
        total_rewards["Ensemble"]["total_reward"] += ensemble_reward
        if ensemble_reward > 0:
            total_rewards["Ensemble"]["win_count"] += 1

        print(f"Ensemble                    : {ensemble_predictions} (당첨금: {ensemble_reward}원)")

    return total_rewards

# 높은 빈도의 숫자를 기반으로 예측
def predict_high_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nlargest(6).index.tolist()  # 상위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 낮은 빈도의 숫자를 기반으로 예측
def predict_low_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nsmallest(6).index.tolist()  # 하위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 높은 빈도 3개 + 낮은 빈도 3개 조합으로 예측
def predict_combined_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    most_frequent = frequency_counts.nlargest(3).index.tolist()  # 상위 3개 숫자
    least_frequent = frequency_counts.nsmallest(3).index.tolist()  # 하위 3개 숫자
    return ensure_unique_numbers(most_frequent + least_frequent)

# PCA를 사용하여 다음 벡터를 예측
def predict_next_vector(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(numbers)  # 데이터 스케일링

    pca = PCA(n_components=1)
    principal_component = pca.fit_transform(scaled_data)  # PCA 변환

    next_vector = principal_component[-1] + (principal_component[-1] - principal_component[-2])  # 다음 벡터 예측
    inverse_scaled_vector = scaler.inverse_transform(scaled_data.mean(axis=0).reshape(1, -1)) + next_vector

    predicted_numbers = [int(round(num)) for num in inverse_scaled_vector[0] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# 신경망을 사용하여 번호를 예측
def predict_neural_network(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(6, activation='sigmoid')  # Using sigmoid to restrict range
    ])

    model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mae'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])

    # Add random noise (jitter) to each prediction
    jittered_predictions = predictions + np.random.uniform(-0.05, 0.05, size=predictions.shape)
    jittered_predictions = np.clip(jittered_predictions, 0, 1)  # Ensure valid range for sigmoid outputs

    # Inverse transform to original scale
    inverse_transformed = scaler_y.inverse_transform(jittered_predictions)

    # Convert to integers and ensure range
    rounded_numbers = [int(round(num)) for num in inverse_transformed.flatten() if 1 <= round(num) <= 45]
    return ensure_unique_numbers(rounded_numbers[:6])

# 랜덤 포레스트를 사용하여 번호를 예측
def predict_random_forest(data, weeks_ago):
    from sklearn.ensemble import RandomForestRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# Gradient Boosting을 사용하여 번호를 예측
def predict_gradient_boosting(data, weeks_ago):
    from sklearn.ensemble import GradientBoostingRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    y_train = y_train.iloc[:, 0].values
    y_test = y_test.iloc[:, 0].values

    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# LSTM을 사용하여 번호를 예측
def predict_lstm(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(numbers)

    X, y = [], []
    for i in range(len(scaled_data) - 10):
        X.append(scaled_data[i:i + 10])
        y.append(scaled_data[i + 10])

    X, y = np.array(X), np.array(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(128, return_sequences=True),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(6, activation='linear')
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])
    predicted_numbers = scaler.inverse_transform(predictions).flatten()
    return ensure_unique_numbers([int(round(num)) for num in predicted_numbers if 1 <= round(num) <= 45])

# Bayesian Optimization을 사용하여 번호를 예측
def predict_bayesian(data, weeks_ago):
    numbers = data.iloc[:, 2:].values

    def objective_function(x):
        selected_numbers = x
        count = sum(num in selected_numbers for num in numbers.flatten())
        return -count

    search_space = [Integer(1, 45) for _ in range(6)]
    result = gp_minimize(objective_function, search_space, n_calls=100)
    return ensure_unique_numbers(result.x)

# K-평균 클러스터링을 사용하여 번호를 예측
def predict_kmeans_clustering(data, weeks_ago, n_clusters=5):
    numbers = data.iloc[:, 2:].values.flatten().reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(numbers)

    # 가장 빈번한 클러스터 선택
    cluster_counts = pd.Series(kmeans.labels_).value_counts()
    top_cluster = cluster_counts.idxmax()
    top_numbers = numbers[kmeans.labels_ == top_cluster]

    # 상위 6개의 번호 선택
    predicted_numbers = pd.Series(top_numbers.flatten()).value_counts().nlargest(6).index.tolist()
    return ensure_unique_numbers(predicted_numbers)

# 오토인코더를 사용하여 번호를 예측
def predict_autoencoder(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(numbers)

    # 오토인코더 정의
    input_dim = scaled_data.shape[1]
    autoencoder = Sequential([
        Input(shape=(input_dim,)),
        Dense(16, activation='relu'),
        Dense(input_dim, activation='sigmoid')
    ])
    autoencoder.compile(optimizer='adam', loss='mse')
    autoencoder.fit(scaled_data, scaled_data, epochs=50, batch_size=16, verbose=0)

    # 복원된 데이터로 패턴 분석
    decoded_data = autoencoder.predict(scaled_data)
    predicted_numbers = [int(round(num)) for num in decoded_data[-1] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# Markov Chain을 사용하여 번호를 예측
def predict_markov_chain(data, weeks_ago):
    numbers = data.iloc[:, 2:].values.flatten()
    transitions = pd.crosstab(numbers[:-1], numbers[1:])
    probabilities = transitions.div(transitions.sum(axis=1), axis=0)

    last_number = numbers[-1]
    if last_number in probabilities.index:
        next_numbers = probabilities.loc[last_number].nlargest(6).index.tolist()
    else:
        next_numbers = random.sample(range(1, 46), 6)  # 기본값으로 랜덤 샘플 제공

    return ensure_unique_numbers(next_numbers)

# 메인 함수
def main():
    try:
        file_path = "Loto_number.xlsx"  # 엑셀 파일 경로
        data = pd.read_excel(file_path)
    except Exception as e:
        print(f"데이터 로드 실패: {e}")
        return

    # 예측 함수 매핑
    prediction_functions = {
        "total_high_frequency        ": predict_high_frequency_numbers,
        "total_low_frequency         ": predict_low_frequency_numbers,
        "total_combined_frequency    ": predict_combined_frequency_numbers,
        "total_next_vector           ": predict_next_vector,

        "recent_52_high_frequency    ": predict_high_frequency_numbers,
        "recent_52_low_frequency     ": predict_low_frequency_numbers,
        "recent_52_combined_frequency": predict_combined_frequency_numbers,
        "recent_52_next_vector       ": predict_next_vector,

        "recent_26_high_frequency    ": predict_high_frequency_numbers,
        "recent_26_low_frequency     ": predict_low_frequency_numbers,
        "recent_26_combined_frequency": predict_combined_frequency_numbers,
        "recent_26_next_vector       ": predict_next_vector,

        "neural_network              ": predict_neural_network,
        "random_forest               ": predict_random_forest,
        "gradient_boosting           ": predict_gradient_boosting,
        "LSTM                        ": predict_lstm,
        "Bayesian                    ": predict_bayesian,
        "KMeans                      ": predict_kmeans_clustering,
        "AutoEncoder                 ": predict_autoencoder,
        "MarkovChain                 ": predict_markov_chain
    }

    # 모델 성능 평가
    total_rewards = evaluate_predictions(data, prediction_functions)

    print("\n### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###")
    for method, stats in total_rewards.items():
        total_reward = stats["total_reward"]
        win_count = stats["win_count"]
        print(f"{method}: 총 당첨 {total_reward}원({win_count}회)")
           
    print("\n### 다음 주 예상 번호 ###")
    all_predictions = []  # 모든 예측 결과를 저장할 리스트
    for method, func in prediction_functions.items():
        try:
            predicted = func(data, weeks_ago=1)
            predicted = ensure_unique_numbers(predicted)
            all_predictions.append(predicted)  # 앙상블에 포함할 결과 저장
            print(f"{method}: {predicted}")
        except Exception as e:
            print(f"{method}: 예측 실패 (오류: {e})")

    # 앙상블 예측 수행
    if all_predictions:
        ensemble_predictions = predict_ensemble_from_numpy([np.array(pred) for pred in all_predictions])
        print(f"\nEnsemble                    : {ensemble_predictions}")

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
import numpy as np
from skopt import gp_minimize
from skopt.space import Integer

# 번호의 중복 제거 및 부족 시 채워주는 함수
def ensure_unique_numbers(numbers):
    numbers = list(set(numbers))  # 중복 제거
    while len(numbers) < 6:
        numbers.append(random.randint(1, 45))  # 부족한 번호를 무작위로 추가
    return sorted(numbers[:6])

# 실제 번호와 예측 번호를 비교하여 보상을 계산하는 함수
def calculate_rewards(actual, predicted):
    match_count = len(set(actual) & set(predicted))  # 일치하는 번호 개수 계산
    rewards = {6: 10_000_000_000, 5: 1_499_000, 4: 49_000, 3: 4_000}
    return rewards.get(match_count, -1_000)  # 일치하지 않으면 -1,000 반환

# 앙상블 예측 함수
def predict_ensemble_from_numpy(predictions_list):
    """
    각 모델의 예측값을 numpy array로 받아 앙상블 예측 수행.
    """
    flat_predictions = np.concatenate(predictions_list).flatten()
    flat_predictions = flat_predictions[(flat_predictions >= 1) & (flat_predictions <= 45)]  # 유효 번호 필터링
    frequency_counts = pd.Series(flat_predictions).value_counts()

    if frequency_counts.empty:
        print("빈도 계산 결과가 없습니다. 빈 결과를 반환합니다.")
        return []

    return ensure_unique_numbers(frequency_counts.nlargest(6).index.tolist())

# 예측 모델의 성능을 평가하는 함수
def evaluate_predictions(data, prediction_functions, weeks_to_evaluate=52):
    total_rewards = {method: {"total_reward": 0, "win_count": 0} for method in prediction_functions.keys()}
    total_rewards["Ensemble"] = {"total_reward": 0, "win_count": 0}  # 앙상블 결과 추가
    prediction_storage = {method: [] for method in prediction_functions.keys()}

    for weeks_ago in range(weeks_to_evaluate, 0, -1):
        train_data = data[:-weeks_ago]
        test_data = data.iloc[-weeks_ago].values[2:]

        print(f"\n### ({weeks_ago}주전)예측되는 번호와 당첨 금액 ###")
        print(f"=> 실제 당첨 번호           : {sorted(test_data)}")

        for method, func in prediction_functions.items():
            predicted = func(train_data, weeks_ago)
            predicted = ensure_unique_numbers(predicted)

            if not predicted:
                print(f"{method}의 예측 결과가 비어 있습니다.")
                continue

            prediction_storage[method].append(predicted)  # 숫자 리스트 저장
            reward = calculate_rewards(test_data, predicted)
            total_rewards[method]["total_reward"] += reward
            if reward > 0:
                total_rewards[method]["win_count"] += 1

            print(f"{method}: {sorted(predicted)} (당첨금: {reward}원)")

        # 앙상블 예측 수행
        ensemble_predictions = predict_ensemble_from_numpy(
            [np.array(prediction_storage[method]) for method in prediction_storage]
        )
        ensemble_reward = calculate_rewards(test_data, ensemble_predictions)
        total_rewards["Ensemble"]["total_reward"] += ensemble_reward
        if ensemble_reward > 0:
            total_rewards["Ensemble"]["win_count"] += 1

        print(f"Ensemble                    : {ensemble_predictions} (당첨금: {ensemble_reward}원)")

    return total_rewards

# 높은 빈도의 숫자를 기반으로 예측
def predict_high_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nlargest(6).index.tolist()  # 상위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 낮은 빈도의 숫자를 기반으로 예측
def predict_low_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    predicted_numbers = frequency_counts.nsmallest(6).index.tolist()  # 하위 6개 숫자 선택
    return ensure_unique_numbers(predicted_numbers)

# 높은 빈도 3개 + 낮은 빈도 3개 조합으로 예측
def predict_combined_frequency_numbers(data, weeks_ago):
    frequency_counts = pd.Series(data.iloc[:, 2:].values.flatten()).value_counts()
    most_frequent = frequency_counts.nlargest(3).index.tolist()  # 상위 3개 숫자
    least_frequent = frequency_counts.nsmallest(3).index.tolist()  # 하위 3개 숫자
    return ensure_unique_numbers(most_frequent + least_frequent)

# PCA를 사용하여 다음 벡터를 예측
def predict_next_vector(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(numbers)  # 데이터 스케일링

    pca = PCA(n_components=1)
    principal_component = pca.fit_transform(scaled_data)  # PCA 변환

    next_vector = principal_component[-1] + (principal_component[-1] - principal_component[-2])  # 다음 벡터 예측
    inverse_scaled_vector = scaler.inverse_transform(scaled_data.mean(axis=0).reshape(1, -1)) + next_vector

    predicted_numbers = [int(round(num)) for num in inverse_scaled_vector[0] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# 신경망을 사용하여 번호를 예측
def predict_neural_network(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(6, activation='sigmoid')  # Using sigmoid to restrict range
    ])

    model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mae'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])

    # Add random noise (jitter) to each prediction
    jittered_predictions = predictions + np.random.uniform(-0.05, 0.05, size=predictions.shape)
    jittered_predictions = np.clip(jittered_predictions, 0, 1)  # Ensure valid range for sigmoid outputs

    # Inverse transform to original scale
    inverse_transformed = scaler_y.inverse_transform(jittered_predictions)

    # Convert to integers and ensure range
    rounded_numbers = [int(round(num)) for num in inverse_transformed.flatten() if 1 <= round(num) <= 45]
    return ensure_unique_numbers(rounded_numbers[:6])

# 랜덤 포레스트를 사용하여 번호를 예측
def predict_random_forest(data, weeks_ago):
    from sklearn.ensemble import RandomForestRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# Gradient Boosting을 사용하여 번호를 예측
def predict_gradient_boosting(data, weeks_ago):
    from sklearn.ensemble import GradientBoostingRegressor

    numbers = data.iloc[:, 2:].values
    X, y = [], []
    for i in range(len(numbers) - 10):
        X.append(numbers[i:i + 10].flatten())
        y.append(numbers[i + 10])

    X, y = pd.DataFrame(X), pd.DataFrame(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    y_train = y_train.iloc[:, 0].values
    y_test = y_test.iloc[:, 0].values

    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test[-weeks_ago:]).flatten()

    # 랜덤 노이즈 추가 및 다양성 확보
    diversified_predictions = predictions + np.random.uniform(-1.5, 1.5, size=predictions.shape)
    rounded_numbers = [int(round(num)) for num in diversified_predictions if 1 <= round(num) <= 45]

    # 중복 제거 및 범위 보장
    return ensure_unique_numbers(rounded_numbers[:6])

# LSTM을 사용하여 번호를 예측
def predict_lstm(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(numbers)

    X, y = [], []
    for i in range(len(scaled_data) - 10):
        X.append(scaled_data[i:i + 10])
        y.append(scaled_data[i + 10])

    X, y = np.array(X), np.array(y)

    split_idx = int(len(X) * 0.7)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(128, return_sequences=True),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(6, activation='linear')
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)

    predictions = model.predict(X_test[-weeks_ago:])
    predicted_numbers = scaler.inverse_transform(predictions).flatten()
    return ensure_unique_numbers([int(round(num)) for num in predicted_numbers if 1 <= round(num) <= 45])

# Bayesian Optimization을 사용하여 번호를 예측
def predict_bayesian(data, weeks_ago):
    numbers = data.iloc[:, 2:].values

    def objective_function(x):
        selected_numbers = x
        count = sum(num in selected_numbers for num in numbers.flatten())
        return -count

    search_space = [Integer(1, 45) for _ in range(6)]
    result = gp_minimize(objective_function, search_space, n_calls=100)
    return ensure_unique_numbers(result.x)

# K-평균 클러스터링을 사용하여 번호를 예측
def predict_kmeans_clustering(data, weeks_ago, n_clusters=5):
    numbers = data.iloc[:, 2:].values.flatten().reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(numbers)

    # 가장 빈번한 클러스터 선택
    cluster_counts = pd.Series(kmeans.labels_).value_counts()
    top_cluster = cluster_counts.idxmax()
    top_numbers = numbers[kmeans.labels_ == top_cluster]

    # 상위 6개의 번호 선택
    predicted_numbers = pd.Series(top_numbers.flatten()).value_counts().nlargest(6).index.tolist()
    return ensure_unique_numbers(predicted_numbers)

# 오토인코더를 사용하여 번호를 예측
def predict_autoencoder(data, weeks_ago):
    numbers = data.iloc[:, 2:].values
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(numbers)

    # 오토인코더 정의
    input_dim = scaled_data.shape[1]
    autoencoder = Sequential([
        Input(shape=(input_dim,)),
        Dense(16, activation='relu'),
        Dense(input_dim, activation='sigmoid')
    ])
    autoencoder.compile(optimizer='adam', loss='mse')
    autoencoder.fit(scaled_data, scaled_data, epochs=50, batch_size=16, verbose=0)

    # 복원된 데이터로 패턴 분석
    decoded_data = autoencoder.predict(scaled_data)
    predicted_numbers = [int(round(num)) for num in decoded_data[-1] if 1 <= round(num) <= 45]
    return ensure_unique_numbers(predicted_numbers)

# Markov Chain을 사용하여 번호를 예측
def predict_markov_chain(data, weeks_ago):
    numbers = data.iloc[:, 2:].values.flatten()
    transitions = pd.crosstab(numbers[:-1], numbers[1:])
    probabilities = transitions.div(transitions.sum(axis=1), axis=0)

    last_number = numbers[-1]
    if last_number in probabilities.index:
        next_numbers = probabilities.loc[last_number].nlargest(6).index.tolist()
    else:
        next_numbers = random.sample(range(1, 46), 6)  # 기본값으로 랜덤 샘플 제공

    return ensure_unique_numbers(next_numbers)

# 메인 함수
def main():
    try:
        file_path = "Loto_number.xlsx"  # 엑셀 파일 경로
        data = pd.read_excel(file_path)
    except Exception as e:
        print(f"데이터 로드 실패: {e}")
        return

    # 예측 함수 매핑
    prediction_functions = {
        "total_high_frequency        ": predict_high_frequency_numbers,
        "total_low_frequency         ": predict_low_frequency_numbers,
        "total_combined_frequency    ": predict_combined_frequency_numbers,
        "total_next_vector           ": predict_next_vector,

        "recent_52_high_frequency    ": predict_high_frequency_numbers,
        "recent_52_low_frequency     ": predict_low_frequency_numbers,
        "recent_52_combined_frequency": predict_combined_frequency_numbers,
        "recent_52_next_vector       ": predict_next_vector,

        "recent_26_high_frequency    ": predict_high_frequency_numbers,
        "recent_26_low_frequency     ": predict_low_frequency_numbers,
        "recent_26_combined_frequency": predict_combined_frequency_numbers,
        "recent_26_next_vector       ": predict_next_vector,

        "neural_network              ": predict_neural_network,
        "random_forest               ": predict_random_forest,
        "gradient_boosting           ": predict_gradient_boosting,
        "LSTM                        ": predict_lstm,
        "Bayesian                    ": predict_bayesian,
        "KMeans                      ": predict_kmeans_clustering,
        "AutoEncoder                 ": predict_autoencoder,
        "MarkovChain                 ": predict_markov_chain
    }

    # 모델 성능 평가
    total_rewards = evaluate_predictions(data, prediction_functions)

    print("\n### 지난 일년(52주) 동안 각각의 방법으로 예측된 총당첨금 ###")
    for method, stats in total_rewards.items():
        total_reward = stats["total_reward"]
        win_count = stats["win_count"]
        print(f"{method}: 총 당첨 {total_reward}원({win_count}회)")
           
    print("\n### 다음 주 예상 번호 ###")
    all_predictions = []  # 모든 예측 결과를 저장할 리스트
    for method, func in prediction_functions.items():
        try:
            predicted = func(data, weeks_ago=1)
            predicted = ensure_unique_numbers(predicted)
            all_predictions.append(predicted)  # 앙상블에 포함할 결과 저장
            print(f"{method}: {predicted}")
        except Exception as e:
            print(f"{method}: 예측 실패 (오류: {e})")

    # 앙상블 예측 수행
    if all_predictions:
        ensemble_predictions = predict_ensemble_from_numpy([np.array(pred) for pred in all_predictions])
        print(f"\nEnsemble                    : {ensemble_predictions}")

if __name__ == "__main__":
    main()
